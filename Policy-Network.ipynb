# %% [markdown]
# # Simple Reinforcement Learning in Tensorflow Part 2: Policy Gradient Method
# This tutorial contains a simple example of how to build a policy-gradient based agent that can solve the CartPole problem. For more information, see this [Medium post](https://medium.com/@awjuliani/super-simple-reinforcement-learning-tutorial-part-2-ded33892c724#.mtwpvfi8b).
#
# For more Reinforcement Learning algorithms, including DQN and Model-based learning in Tensorflow, see my Github repo, [DeepRL-Agents](https://github.com/awjuliani/DeepRL-Agents).
#
# Parts of this tutorial are based on code by [Andrej Karpathy](https://gist.github.com/karpathy/a4166c7fe253700972fcbc77e4ea32c5) and [korymath](https://gym.openai.com/evaluations/eval_a0aVJrGSyW892vBM04HQA).

# %%
from __future__ import division

import numpy as np
try:
    import cPickle as pickle
except:
    import pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math

try:
    xrange = xrange
except:
    xrange = range

# %% [markdown]
# ### Loading the CartPole Environment
# If you don't already have the OpenAI gym installed, use  `pip install gym` to grab it.

# %%
import gym
env = gym.make('CartPole-v0')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %% [markdown]
# What happens if we try running the environment with random actions? How well do we do? (Hint: not so well.)

# %%
env.reset()
random_episodes = 0
reward_sum = 0
while random_episodes < 10:
    env.render()
    observation, reward, done, _ = env.step(np.random.randint(0,2))
    reward_sum += reward
    if done:
        random_episodes += 1
        print("Reward for this episode was:",reward_sum)
        reward_sum = 0
        env.reset()
# Out:
# Reward for this episode was: 14.0
# Reward for this episode was: 33.0
# Reward for this episode was: 29.0
# Reward for this episode was: 27.0
# Reward for this episode was: 22.0
# Reward for this episode was: 9.0
# Reward for this episode was: 24.0
# Reward for this episode was: 21.0
# Reward for this episode was: 14.0
# Reward for this episode was: 24.0

# %% [markdown]
# The goal of the task is to achieve a reward of 200 per episode. For every step the agent keeps the pole in the air, the agent recieves a +1 reward. By randomly choosing actions, our reward for each episode is only a couple dozen. Let's make that better with RL!

# %% [markdown]
# ### Setting up our Neural Network agent
# This time we will be using a Policy neural network that takes observations, passes them through a single hidden layer, and then produces a probability of choosing a left/right movement. To learn more about this network, see [Andrej Karpathy's blog on Policy Gradient networks](http://karpathy.github.io/2016/05/31/rl/).

# %%
# hyperparameters
H = 10 # number of hidden layer neurons
batch_size = 5 # every how many episodes to do a param update?
learning_rate = 1e-2 # feel free to play with this to train faster or more stably.
gamma = 0.99 # discount factor for reward

D = 4 # input dimensionality

# %%
tf.reset_default_graph()

#This defines the network as it goes from taking an observation of the environment to 
#giving a probability of chosing to the action of moving left or right.
observations = tf.placeholder(tf.float32, [None,D] , name="input_x")
W1 = tf.get_variable("W1", shape=[D, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

#From here we define the parts of the network needed for learning a good policy.
tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")

# The loss function. This sends the weights in the direction of making actions 
# that gave good advantage (reward over time) more likely, and actions that didn't less likely.
loglik = tf.log(input_y*(input_y - probability) + (1 - input_y)*(input_y + probability))
loss = -tf.reduce_mean(loglik * advantages) 
newGrads = tf.gradients(loss,tvars)

# Once we have collected a series of gradients from multiple episodes, we apply them.
# We don't just apply gradeients after every episode in order to account for noise in the reward signal.
adam = tf.train.AdamOptimizer(learning_rate=learning_rate) # Our optimizer
W1Grad = tf.placeholder(tf.float32,name="batch_grad1") # Placeholders to send the final gradients through when we update.
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %% [markdown]
# ### Advantage function
# This function allows us to weigh the rewards our agent recieves. In the context of the Cart-Pole task, we want actions that kept the pole in the air a long time to have a large reward, and actions that contributed to the pole falling to have a decreased or negative reward. We do this by weighing the rewards from the end of the episode, with actions at the end being seen as negative, since they likely contributed to the pole falling, and the episode ending. Likewise, early actions are seen as more positive, since they weren't responsible for the pole falling.

# %%
def discount_rewards(r):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_add = 0
    for t in reversed(xrange(0, r.size)):
        running_add = running_add * gamma + r[t]
        discounted_r[t] = running_add
    return discounted_r

# %% [markdown]
# ### Running the Agent and Environment

# %% [markdown]
# Here we run the neural network agent, and have it act in the CartPole environment.

# %%
xs,hs,dlogps,drs,ys,tfps = [],[],[],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
total_episodes = 10000
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    rendering = False
    sess.run(init)
    observation = env.reset() # Obtain an initial observation of the environment

    # Reset the gradient placeholder. We will collect gradients in 
    # gradBuffer until we are ready to update our policy network. 
    gradBuffer = sess.run(tvars)
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    
    while episode_number <= total_episodes:
        
        # Rendering the environment slows things down, 
        # so let's only look at it once our agent is doing a good job.
        if reward_sum/batch_size > 100 or rendering == True : 
            env.render()
            rendering = True
            
        # Make sure the observation is in a shape the network can handle.
        x = np.reshape(observation,[1,D])
        
        # Run the policy network and get an action to take. 
        tfprob = sess.run(probability,feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0
        
        xs.append(x) # observation
        y = 1 if action == 0 else 0 # a "fake label"
        ys.append(y)

        # step the environment and get new measurements
        observation, reward, done, info = env.step(action)
        reward_sum += reward

        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: 
            episode_number += 1
            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            tfp = tfps
            xs,hs,dlogps,drs,ys,tfps = [],[],[],[],[],[] # reset array memory

            # compute the discounted reward backwards through time
            discounted_epr = discount_rewards(epr)
            # size the rewards to be unit normal (helps control the gradient estimator variance)
            discounted_epr -= np.mean(discounted_epr)
            discounted_epr //= np.std(discounted_epr)
            
            # Get the gradient for this episode, and save it in the gradBuffer
            tGrad = sess.run(newGrads,feed_dict={observations: epx, input_y: epy, advantages: discounted_epr})
            for ix,grad in enumerate(tGrad):
                gradBuffer[ix] += grad
                
            # If we have completed enough episodes, then update the policy network with our gradients.
            if episode_number % batch_size == 0: 
                sess.run(updateGrads,feed_dict={W1Grad: gradBuffer[0],W2Grad:gradBuffer[1]})
                for ix,grad in enumerate(gradBuffer):
                    gradBuffer[ix] = grad * 0
                
                # Give a summary of how well our network is doing for each batch of episodes.
                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                print('Average reward for episode %f.  Total average reward %f.' % (reward_sum//batch_size, running_reward//batch_size))
                
                if reward_sum//batch_size > 200: 
                    print("Task solved in",episode_number,'episodes!')
                    break
                    
                reward_sum = 0
            
            observation = env.reset()
        
print(episode_number,'Episodes completed.')
# Out:
# Average reward for episode 19.000000.  Total average reward 19.000000.
# Average reward for episode 15.000000.  Total average reward 19.000000.
# Average reward for episode 15.000000.  Total average reward 19.000000.
# Average reward for episode 13.000000.  Total average reward 19.000000.
# Average reward for episode 25.000000.  Total average reward 19.000000.
# Average reward for episode 13.000000.  Total average reward 19.000000.
# Average reward for episode 14.000000.  Total average reward 19.000000.
# Average reward for episode 25.000000.  Total average reward 19.000000.
# Average reward for episode 24.000000.  Total average reward 19.000000.
# Average reward for episode 19.000000.  Total average reward 19.000000.
# Average reward for episode 14.000000.  Total average reward 19.000000.
# Average reward for episode 15.000000.  Total average reward 19.000000.
# Average reward for episode 16.000000.  Total average reward 19.000000.
# Average reward for episode 18.000000.  Total average reward 19.000000.
# Average reward for episode 16.000000.  Total average reward 19.000000.
# Average reward for episode 17.000000.  Total average reward 18.000000.
# Average reward for episode 22.000000.  Total average reward 19.000000.
# Average reward for episode 20.000000.  Total average reward 19.000000.
# Average reward for episode 15.000000.  Total average reward 19.000000.
# Average reward for episode 19.000000.  Total average reward 19.000000.
# Average reward for episode 23.000000.  Total average reward 19.000000.
# Average reward for episode 26.000000.  Total average reward 19.000000.
# Average reward for episode 22.000000.  Total average reward 19.000000.
# Average reward for episode 18.000000.  Total average reward 19.000000.
# Average reward for episode 27.000000.  Total average reward 19.000000.
# Average reward for episode 21.000000.  Total average reward 19.000000.
# Average reward for episode 30.000000.  Total average reward 19.000000.
# Average reward for episode 31.000000.  Total average reward 19.000000.
# Average reward for episode 33.000000.  Total average reward 19.000000.
# Average reward for episode 16.000000.  Total average reward 19.000000.
# Average reward for episode 18.000000.  Total average reward 19.000000.
# Average reward for episode 22.000000.  Total average reward 19.000000.
# Average reward for episode 27.000000.  Total average reward 19.000000.
# Average reward for episode 41.000000.  Total average reward 19.000000.
# Average reward for episode 24.000000.  Total average reward 19.000000.
# Average reward for episode 33.000000.  Total average reward 20.000000.
# Average reward for episode 28.000000.  Total average reward 20.000000.
# Average reward for episode 29.000000.  Total average reward 20.000000.
# Average reward for episode 26.000000.  Total average reward 20.000000.
# Average reward for episode 20.000000.  Total average reward 20.000000.
# Average reward for episode 22.000000.  Total average reward 20.000000.
# Average reward for episode 33.000000.  Total average reward 20.000000.
# Average reward for episode 29.000000.  Total average reward 20.000000.
# Average reward for episode 34.000000.  Total average reward 20.000000.
# Average reward for episode 29.000000.  Total average reward 20.000000.
# Average reward for episode 21.000000.  Total average reward 20.000000.
# Average reward for episode 29.000000.  Total average reward 20.000000.
# Average reward for episode 26.000000.  Total average reward 20.000000.
# Average reward for episode 17.000000.  Total average reward 20.000000.
# Average reward for episode 22.000000.  Total average reward 20.000000.
# Average reward for episode 44.000000.  Total average reward 21.000000.
# Average reward for episode 26.000000.  Total average reward 21.000000.
# Average reward for episode 30.000000.  Total average reward 21.000000.
# Average reward for episode 45.000000.  Total average reward 21.000000.
# Average reward for episode 43.000000.  Total average reward 21.000000.
# Average reward for episode 18.000000.  Total average reward 21.000000.
# Average reward for episode 45.000000.  Total average reward 21.000000.
# Average reward for episode 32.000000.  Total average reward 22.000000.
# Average reward for episode 31.000000.  Total average reward 22.000000.
# Average reward for episode 22.000000.  Total average reward 22.000000.
# Average reward for episode 26.000000.  Total average reward 22.000000.
# Average reward for episode 29.000000.  Total average reward 22.000000.
# Average reward for episode 34.000000.  Total average reward 22.000000.
# Average reward for episode 24.000000.  Total average reward 22.000000.
# Average reward for episode 33.000000.  Total average reward 22.000000.
# Average reward for episode 23.000000.  Total average reward 22.000000.
# Average reward for episode 32.000000.  Total average reward 22.000000.
# Average reward for episode 34.000000.  Total average reward 22.000000.
# Average reward for episode 35.000000.  Total average reward 22.000000.
# Average reward for episode 34.000000.  Total average reward 22.000000.
# Average reward for episode 28.000000.  Total average reward 23.000000.
# Average reward for episode 32.000000.  Total average reward 23.000000.
# Average reward for episode 31.000000.  Total average reward 23.000000.
# Average reward for episode 22.000000.  Total average reward 23.000000.
# Average reward for episode 31.000000.  Total average reward 23.000000.
# Average reward for episode 37.000000.  Total average reward 23.000000.
# Average reward for episode 27.000000.  Total average reward 23.000000.
# Average reward for episode 27.000000.  Total average reward 23.000000.
# Average reward for episode 28.000000.  Total average reward 23.000000.
# Average reward for episode 33.000000.  Total average reward 23.000000.
# Average reward for episode 25.000000.  Total average reward 23.000000.
# Average reward for episode 22.000000.  Total average reward 23.000000.
# Average reward for episode 33.000000.  Total average reward 23.000000.
# Average reward for episode 34.000000.  Total average reward 23.000000.
# Average reward for episode 38.000000.  Total average reward 23.000000.
# Average reward for episode 40.000000.  Total average reward 24.000000.
# Average reward for episode 29.000000.  Total average reward 24.000000.
# Average reward for episode 33.000000.  Total average reward 24.000000.
# Average reward for episode 35.000000.  Total average reward 24.000000.
# Average reward for episode 25.000000.  Total average reward 24.000000.
# Average reward for episode 39.000000.  Total average reward 24.000000.
# Average reward for episode 22.000000.  Total average reward 24.000000.
# Average reward for episode 56.000000.  Total average reward 24.000000.
# Average reward for episode 29.000000.  Total average reward 24.000000.
# Average reward for episode 37.000000.  Total average reward 25.000000.
# Average reward for episode 36.000000.  Total average reward 25.000000.
# Average reward for episode 51.000000.  Total average reward 25.000000.
# Average reward for episode 24.000000.  Total average reward 25.000000.
# Average reward for episode 30.000000.  Total average reward 25.000000.
# Average reward for episode 37.000000.  Total average reward 25.000000.
# Average reward for episode 36.000000.  Total average reward 25.000000.
# Average reward for episode 28.000000.  Total average reward 25.000000.
# Average reward for episode 23.000000.  Total average reward 25.000000.
# Average reward for episode 32.000000.  Total average reward 25.000000.
# Average reward for episode 29.000000.  Total average reward 25.000000.
# Average reward for episode 35.000000.  Total average reward 25.000000.
# Average reward for episode 38.000000.  Total average reward 26.000000.
# Average reward for episode 29.000000.  Total average reward 26.000000.
# Average reward for episode 33.000000.  Total average reward 26.000000.
# Average reward for episode 48.000000.  Total average reward 26.000000.
# Average reward for episode 40.000000.  Total average reward 26.000000.
# Average reward for episode 43.000000.  Total average reward 26.000000.
# Average reward for episode 37.000000.  Total average reward 26.000000.
# Average reward for episode 28.000000.  Total average reward 26.000000.
# Average reward for episode 36.000000.  Total average reward 26.000000.
# Average reward for episode 34.000000.  Total average reward 26.000000.
# Average reward for episode 51.000000.  Total average reward 27.000000.
# Average reward for episode 45.000000.  Total average reward 27.000000.
# Average reward for episode 42.000000.  Total average reward 27.000000.
# Average reward for episode 68.000000.  Total average reward 27.000000.
# Average reward for episode 39.000000.  Total average reward 28.000000.
# Average reward for episode 38.000000.  Total average reward 28.000000.
# Average reward for episode 44.000000.  Total average reward 28.000000.
# Average reward for episode 49.000000.  Total average reward 28.000000.
# Average reward for episode 40.000000.  Total average reward 28.000000.
# Average reward for episode 30.000000.  Total average reward 28.000000.
# Average reward for episode 59.000000.  Total average reward 28.000000.
# Average reward for episode 58.000000.  Total average reward 29.000000.
# Average reward for episode 48.000000.  Total average reward 29.000000.
# Average reward for episode 54.000000.  Total average reward 29.000000.
# Average reward for episode 38.000000.  Total average reward 29.000000.
# Average reward for episode 49.000000.  Total average reward 30.000000.
# Average reward for episode 57.000000.  Total average reward 30.000000.
# Average reward for episode 55.000000.  Total average reward 30.000000.
# Average reward for episode 49.000000.  Total average reward 30.000000.
# Average reward for episode 45.000000.  Total average reward 30.000000.
# Average reward for episode 42.000000.  Total average reward 30.000000.
# Average reward for episode 64.000000.  Total average reward 31.000000.
# Average reward for episode 54.000000.  Total average reward 31.000000.
# Average reward for episode 78.000000.  Total average reward 32.000000.
# Average reward for episode 51.000000.  Total average reward 32.000000.
# Average reward for episode 64.000000.  Total average reward 32.000000.
# Average reward for episode 74.000000.  Total average reward 32.000000.
# Average reward for episode 52.000000.  Total average reward 33.000000.
# Average reward for episode 62.000000.  Total average reward 33.000000.
# Average reward for episode 62.000000.  Total average reward 33.000000.
# Average reward for episode 59.000000.  Total average reward 33.000000.
# Average reward for episode 72.000000.  Total average reward 34.000000.
# Average reward for episode 61.000000.  Total average reward 34.000000.
# Average reward for episode 60.000000.  Total average reward 34.000000.
# Average reward for episode 71.000000.  Total average reward 35.000000.
# Average reward for episode 55.000000.  Total average reward 35.000000.
# Average reward for episode 58.000000.  Total average reward 35.000000.
# Average reward for episode 67.000000.  Total average reward 36.000000.
# Average reward for episode 64.000000.  Total average reward 36.000000.
# Average reward for episode 57.000000.  Total average reward 36.000000.
# Average reward for episode 59.000000.  Total average reward 36.000000.
# Average reward for episode 55.000000.  Total average reward 36.000000.
# Average reward for episode 65.000000.  Total average reward 37.000000.
# Average reward for episode 77.000000.  Total average reward 37.000000.
# Average reward for episode 67.000000.  Total average reward 37.000000.
# Average reward for episode 78.000000.  Total average reward 38.000000.
# Average reward for episode 48.000000.  Total average reward 38.000000.
# Average reward for episode 54.000000.  Total average reward 38.000000.
# Average reward for episode 80.000000.  Total average reward 38.000000.
# Average reward for episode 128.000000.  Total average reward 39.000000.
# Average reward for episode 41.000000.  Total average reward 39.000000.
# Average reward for episode 81.000000.  Total average reward 40.000000.
# Average reward for episode 73.000000.  Total average reward 40.000000.
# Average reward for episode 92.000000.  Total average reward 41.000000.
# Average reward for episode 109.000000.  Total average reward 41.000000.
# Average reward for episode 84.000000.  Total average reward 42.000000.
# Average reward for episode 141.000000.  Total average reward 43.000000.
# Average reward for episode 100.000000.  Total average reward 43.000000.
# Average reward for episode 98.000000.  Total average reward 44.000000.
# Average reward for episode 135.000000.  Total average reward 45.000000.
# Average reward for episode 132.000000.  Total average reward 46.000000.
# Average reward for episode 162.000000.  Total average reward 47.000000.
# Average reward for episode 138.000000.  Total average reward 48.000000.
# Average reward for episode 96.000000.  Total average reward 48.000000.
# Average reward for episode 103.000000.  Total average reward 49.000000.
# Average reward for episode 75.000000.  Total average reward 49.000000.
# Average reward for episode 110.000000.  Total average reward 50.000000.
# Average reward for episode 110.000000.  Total average reward 50.000000.
# Average reward for episode 116.000000.  Total average reward 51.000000.
# Average reward for episode 165.000000.  Total average reward 52.000000.
# Average reward for episode 109.000000.  Total average reward 53.000000.
# Average reward for episode 144.000000.  Total average reward 54.000000.
# Average reward for episode 158.000000.  Total average reward 55.000000.
# Average reward for episode 113.000000.  Total average reward 55.000000.
# Average reward for episode 126.000000.  Total average reward 56.000000.
# Average reward for episode 118.000000.  Total average reward 56.000000.
# Average reward for episode 108.000000.  Total average reward 57.000000.
# Average reward for episode 87.000000.  Total average reward 57.000000.
# Average reward for episode 148.000000.  Total average reward 58.000000.
# Average reward for episode 128.000000.  Total average reward 59.000000.
# Average reward for episode 149.000000.  Total average reward 60.000000.
# Average reward for episode 126.000000.  Total average reward 60.000000.
# Average reward for episode 138.000000.  Total average reward 61.000000.
# Average reward for episode 113.000000.  Total average reward 62.000000.
# Average reward for episode 80.000000.  Total average reward 62.000000.
# Average reward for episode 137.000000.  Total average reward 63.000000.
# Average reward for episode 143.000000.  Total average reward 63.000000.
# Average reward for episode 85.000000.  Total average reward 64.000000.
# Average reward for episode 185.000000.  Total average reward 65.000000.
# Average reward for episode 133.000000.  Total average reward 66.000000.
# Average reward for episode 133.000000.  Total average reward 66.000000.
# Average reward for episode 138.000000.  Total average reward 67.000000.
# Average reward for episode 166.000000.  Total average reward 68.000000.
# Average reward for episode 191.000000.  Total average reward 69.000000.
# Average reward for episode 200.000000.  Total average reward 70.000000.
# Average reward for episode 150.000000.  Total average reward 71.000000.
# Average reward for episode 117.000000.  Total average reward 72.000000.
# Average reward for episode 183.000000.  Total average reward 73.000000.
# Average reward for episode 193.000000.  Total average reward 74.000000.
# Average reward for episode 131.000000.  Total average reward 75.000000.
# Average reward for episode 163.000000.  Total average reward 76.000000.
# Average reward for episode 169.000000.  Total average reward 76.000000.
# Average reward for episode 192.000000.  Total average reward 78.000000.
# Average reward for episode 134.000000.  Total average reward 78.000000.
# Average reward for episode 195.000000.  Total average reward 79.000000.
# Average reward for episode 172.000000.  Total average reward 80.000000.
# Average reward for episode 166.000000.  Total average reward 81.000000.
# Average reward for episode 154.000000.  Total average reward 82.000000.
# Average reward for episode 154.000000.  Total average reward 83.000000.
# Average reward for episode 176.000000.  Total average reward 83.000000.
# Average reward for episode 194.000000.  Total average reward 85.000000.
# Average reward for episode 175.000000.  Total average reward 85.000000.
# Average reward for episode 156.000000.  Total average reward 86.000000.
# Average reward for episode 200.000000.  Total average reward 87.000000.
# Average reward for episode 200.000000.  Total average reward 88.000000.
# Average reward for episode 182.000000.  Total average reward 89.000000.
# Average reward for episode 177.000000.  Total average reward 90.000000.
# Average reward for episode 192.000000.  Total average reward 91.000000.
# Average reward for episode 150.000000.  Total average reward 92.000000.
# Average reward for episode 183.000000.  Total average reward 93.000000.
# Average reward for episode 168.000000.  Total average reward 94.000000.
# Average reward for episode 198.000000.  Total average reward 95.000000.
# Average reward for episode 191.000000.  Total average reward 96.000000.
# Average reward for episode 194.000000.  Total average reward 97.000000.
# Average reward for episode 173.000000.  Total average reward 97.000000.
# Average reward for episode 200.000000.  Total average reward 98.000000.
# Average reward for episode 200.000000.  Total average reward 99.000000.
# Average reward for episode 161.000000.  Total average reward 100.000000.
# Average reward for episode 155.000000.  Total average reward 100.000000.
# Average reward for episode 174.000000.  Total average reward 101.000000.
# Average reward for episode 187.000000.  Total average reward 102.000000.
# Average reward for episode 173.000000.  Total average reward 103.000000.
# Average reward for episode 171.000000.  Total average reward 103.000000.
# Average reward for episode 200.000000.  Total average reward 104.000000.
# Average reward for episode 185.000000.  Total average reward 105.000000.
# Average reward for episode 157.000000.  Total average reward 106.000000.
# Average reward for episode 186.000000.  Total average reward 107.000000.
# Average reward for episode 163.000000.  Total average reward 107.000000.
# Average reward for episode 188.000000.  Total average reward 108.000000.
# Average reward for episode 174.000000.  Total average reward 109.000000.
# Average reward for episode 196.000000.  Total average reward 109.000000.
# Average reward for episode 189.000000.  Total average reward 110.000000.
# Average reward for episode 151.000000.  Total average reward 111.000000.
# Average reward for episode 178.000000.  Total average reward 111.000000.
# Average reward for episode 189.000000.  Total average reward 112.000000.
# Average reward for episode 161.000000.  Total average reward 113.000000.
# Average reward for episode 177.000000.  Total average reward 113.000000.
# Average reward for episode 192.000000.  Total average reward 114.000000.
# Average reward for episode 194.000000.  Total average reward 115.000000.
# Average reward for episode 185.000000.  Total average reward 116.000000.
# Average reward for episode 189.000000.  Total average reward 116.000000.
# Average reward for episode 174.000000.  Total average reward 117.000000.
# Average reward for episode 178.000000.  Total average reward 117.000000.
# Average reward for episode 200.000000.  Total average reward 118.000000.
# Average reward for episode 174.000000.  Total average reward 119.000000.
# Average reward for episode 158.000000.  Total average reward 119.000000.
# Average reward for episode 184.000000.  Total average reward 120.000000.
# Average reward for episode 194.000000.  Total average reward 121.000000.
# Average reward for episode 192.000000.  Total average reward 121.000000.
# Average reward for episode 186.000000.  Total average reward 122.000000.
# Average reward for episode 157.000000.  Total average reward 122.000000.
# Average reward for episode 150.000000.  Total average reward 123.000000.
# Average reward for episode 191.000000.  Total average reward 123.000000.
# Average reward for episode 200.000000.  Total average reward 124.000000.
# Average reward for episode 183.000000.  Total average reward 125.000000.
# Average reward for episode 157.000000.  Total average reward 125.000000.
# Average reward for episode 181.000000.  Total average reward 126.000000.
# Average reward for episode 192.000000.  Total average reward 126.000000.
# Average reward for episode 200.000000.  Total average reward 127.000000.
# Average reward for episode 167.000000.  Total average reward 127.000000.
# Average reward for episode 199.000000.  Total average reward 128.000000.
# Average reward for episode 167.000000.  Total average reward 128.000000.
# Average reward for episode 194.000000.  Total average reward 129.000000.
# Average reward for episode 200.000000.  Total average reward 130.000000.
# Average reward for episode 197.000000.  Total average reward 130.000000.
# Average reward for episode 174.000000.  Total average reward 131.000000.
# Average reward for episode 200.000000.  Total average reward 132.000000.
# Average reward for episode 191.000000.  Total average reward 132.000000.
# Average reward for episode 199.000000.  Total average reward 133.000000.
# Average reward for episode 200.000000.  Total average reward 133.000000.
# Average reward for episode 190.000000.  Total average reward 134.000000.
# Average reward for episode 200.000000.  Total average reward 135.000000.
# Average reward for episode 200.000000.  Total average reward 135.000000.
# Average reward for episode 199.000000.  Total average reward 136.000000.
# Average reward for episode 200.000000.  Total average reward 137.000000.
# Average reward for episode 200.000000.  Total average reward 137.000000.
# Average reward for episode 190.000000.  Total average reward 138.000000.
# Average reward for episode 200.000000.  Total average reward 138.000000.
# Average reward for episode 198.000000.  Total average reward 139.000000.
# Average reward for episode 195.000000.  Total average reward 140.000000.
# Average reward for episode 167.000000.  Total average reward 140.000000.
# Average reward for episode 195.000000.  Total average reward 140.000000.
# Average reward for episode 200.000000.  Total average reward 141.000000.
# Average reward for episode 200.000000.  Total average reward 142.000000.
# Average reward for episode 173.000000.  Total average reward 142.000000.
# Average reward for episode 200.000000.  Total average reward 142.000000.
# Average reward for episode 200.000000.  Total average reward 143.000000.
# Average reward for episode 179.000000.  Total average reward 143.000000.
# Average reward for episode 178.000000.  Total average reward 144.000000.
# Average reward for episode 191.000000.  Total average reward 144.000000.
# Average reward for episode 200.000000.  Total average reward 145.000000.
# Average reward for episode 193.000000.  Total average reward 145.000000.
# Average reward for episode 199.000000.  Total average reward 146.000000.
# Average reward for episode 182.000000.  Total average reward 146.000000.
# Average reward for episode 200.000000.  Total average reward 147.000000.
# Average reward for episode 200.000000.  Total average reward 147.000000.
# Average reward for episode 194.000000.  Total average reward 148.000000.
# Average reward for episode 176.000000.  Total average reward 148.000000.
# Average reward for episode 190.000000.  Total average reward 148.000000.
# Average reward for episode 200.000000.  Total average reward 149.000000.
# Average reward for episode 184.000000.  Total average reward 149.000000.
# Average reward for episode 191.000000.  Total average reward 150.000000.
# Average reward for episode 200.000000.  Total average reward 150.000000.
# Average reward for episode 183.000000.  Total average reward 150.000000.
# Average reward for episode 185.000000.  Total average reward 151.000000.
# Average reward for episode 200.000000.  Total average reward 151.000000.
# Average reward for episode 200.000000.  Total average reward 152.000000.
# Average reward for episode 191.000000.  Total average reward 152.000000.
# Average reward for episode 195.000000.  Total average reward 153.000000.
# Average reward for episode 177.000000.  Total average reward 153.000000.
# Average reward for episode 176.000000.  Total average reward 153.000000.
# Average reward for episode 189.000000.  Total average reward 153.000000.
# Average reward for episode 200.000000.  Total average reward 154.000000.
# Average reward for episode 200.000000.  Total average reward 154.000000.
# Average reward for episode 200.000000.  Total average reward 155.000000.
# Average reward for episode 182.000000.  Total average reward 155.000000.
# Average reward for episode 200.000000.  Total average reward 156.000000.
# Average reward for episode 200.000000.  Total average reward 156.000000.
# Average reward for episode 194.000000.  Total average reward 156.000000.
# Average reward for episode 200.000000.  Total average reward 157.000000.
# Average reward for episode 200.000000.  Total average reward 157.000000.
# Average reward for episode 197.000000.  Total average reward 158.000000.
# Average reward for episode 175.000000.  Total average reward 158.000000.
# Average reward for episode 200.000000.  Total average reward 158.000000.
# Average reward for episode 200.000000.  Total average reward 159.000000.
# Average reward for episode 200.000000.  Total average reward 159.000000.
# Average reward for episode 195.000000.  Total average reward 159.000000.
# Average reward for episode 200.000000.  Total average reward 160.000000.
# Average reward for episode 200.000000.  Total average reward 160.000000.
# Average reward for episode 200.000000.  Total average reward 161.000000.
# Average reward for episode 193.000000.  Total average reward 161.000000.
# Average reward for episode 188.000000.  Total average reward 161.000000.
# Average reward for episode 200.000000.  Total average reward 162.000000.
# Average reward for episode 200.000000.  Total average reward 162.000000.
# Average reward for episode 177.000000.  Total average reward 162.000000.
# Average reward for episode 196.000000.  Total average reward 162.000000.
# Average reward for episode 198.000000.  Total average reward 163.000000.
# Average reward for episode 200.000000.  Total average reward 163.000000.
# Average reward for episode 200.000000.  Total average reward 163.000000.
# Average reward for episode 195.000000.  Total average reward 164.000000.
# Average reward for episode 184.000000.  Total average reward 164.000000.
# Average reward for episode 200.000000.  Total average reward 164.000000.
# Average reward for episode 190.000000.  Total average reward 165.000000.
# Average reward for episode 186.000000.  Total average reward 165.000000.
# Average reward for episode 200.000000.  Total average reward 165.000000.
# Average reward for episode 200.000000.  Total average reward 166.000000.
# Average reward for episode 200.000000.  Total average reward 166.000000.
# Average reward for episode 192.000000.  Total average reward 166.000000.
# Average reward for episode 200.000000.  Total average reward 166.000000.
# Average reward for episode 178.000000.  Total average reward 167.000000.
# Average reward for episode 200.000000.  Total average reward 167.000000.
# Average reward for episode 200.000000.  Total average reward 167.000000.
# Average reward for episode 200.000000.  Total average reward 168.000000.
# Average reward for episode 175.000000.  Total average reward 168.000000.
# Average reward for episode 200.000000.  Total average reward 168.000000.
# Average reward for episode 200.000000.  Total average reward 168.000000.
# Average reward for episode 200.000000.  Total average reward 169.000000.
# Average reward for episode 200.000000.  Total average reward 169.000000.
# Average reward for episode 199.000000.  Total average reward 169.000000.
# Average reward for episode 200.000000.  Total average reward 169.000000.
# Average reward for episode 194.000000.  Total average reward 170.000000.
# Average reward for episode 200.000000.  Total average reward 170.000000.
# Average reward for episode 200.000000.  Total average reward 170.000000.
# Average reward for episode 192.000000.  Total average reward 171.000000.
# Average reward for episode 200.000000.  Total average reward 171.000000.
# Average reward for episode 193.000000.  Total average reward 171.000000.
# Average reward for episode 200.000000.  Total average reward 171.000000.
# Average reward for episode 200.000000.  Total average reward 172.000000.
# Average reward for episode 200.000000.  Total average reward 172.000000.
# Average reward for episode 200.000000.  Total average reward 172.000000.
# Average reward for episode 200.000000.  Total average reward 172.000000.
# Average reward for episode 200.000000.  Total average reward 173.000000.
# Average reward for episode 200.000000.  Total average reward 173.000000.
# Average reward for episode 200.000000.  Total average reward 173.000000.
# Average reward for episode 200.000000.  Total average reward 173.000000.
# Average reward for episode 184.000000.  Total average reward 174.000000.
# Average reward for episode 200.000000.  Total average reward 174.000000.
# Average reward for episode 200.000000.  Total average reward 174.000000.
# Average reward for episode 200.000000.  Total average reward 174.000000.
# Average reward for episode 200.000000.  Total average reward 175.000000.
# Average reward for episode 200.000000.  Total average reward 175.000000.
# Average reward for episode 199.000000.  Total average reward 175.000000.
# Average reward for episode 200.000000.  Total average reward 175.000000.
# Average reward for episode 200.000000.  Total average reward 176.000000.
# Average reward for episode 198.000000.  Total average reward 176.000000.
# Average reward for episode 200.000000.  Total average reward 176.000000.
# Average reward for episode 200.000000.  Total average reward 176.000000.
# Average reward for episode 200.000000.  Total average reward 177.000000.
# Average reward for episode 196.000000.  Total average reward 177.000000.
# Average reward for episode 200.000000.  Total average reward 177.000000.
# Average reward for episode 200.000000.  Total average reward 177.000000.
# Average reward for episode 200.000000.  Total average reward 177.000000.
# Average reward for episode 200.000000.  Total average reward 178.000000.
# Average reward for episode 200.000000.  Total average reward 178.000000.
# Average reward for episode 200.000000.  Total average reward 178.000000.
# Average reward for episode 200.000000.  Total average reward 178.000000.
# Average reward for episode 200.000000.  Total average reward 178.000000.
# Average reward for episode 200.000000.  Total average reward 179.000000.
# Average reward for episode 200.000000.  Total average reward 179.000000.
# Average reward for episode 200.000000.  Total average reward 179.000000.
# Average reward for episode 200.000000.  Total average reward 179.000000.
# Average reward for episode 200.000000.  Total average reward 180.000000.
# Average reward for episode 200.000000.  Total average reward 180.000000.
# Average reward for episode 200.000000.  Total average reward 180.000000.
# Average reward for episode 200.000000.  Total average reward 180.000000.
# Average reward for episode 200.000000.  Total average reward 180.000000.
# Average reward for episode 200.000000.  Total average reward 180.000000.
# Average reward for episode 200.000000.  Total average reward 181.000000.
# Average reward for episode 200.000000.  Total average reward 181.000000.
# Average reward for episode 200.000000.  Total average reward 181.000000.
# Average reward for episode 200.000000.  Total average reward 181.000000.
# Average reward for episode 200.000000.  Total average reward 181.000000.
# Average reward for episode 200.000000.  Total average reward 182.000000.
# Average reward for episode 194.000000.  Total average reward 182.000000.
# Average reward for episode 186.000000.  Total average reward 182.000000.
# Average reward for episode 200.000000.  Total average reward 182.000000.
# Average reward for episode 200.000000.  Total average reward 182.000000.
# Average reward for episode 200.000000.  Total average reward 182.000000.
# Average reward for episode 200.000000.  Total average reward 182.000000.
# Average reward for episode 199.000000.  Total average reward 183.000000.
# Average reward for episode 187.000000.  Total average reward 183.000000.
# Average reward for episode 178.000000.  Total average reward 183.000000.
# Average reward for episode 190.000000.  Total average reward 183.000000.
# Average reward for episode 200.000000.  Total average reward 183.000000.
# Average reward for episode 200.000000.  Total average reward 183.000000.
# Average reward for episode 192.000000.  Total average reward 183.000000.
# Average reward for episode 189.000000.  Total average reward 183.000000.
# Average reward for episode 200.000000.  Total average reward 183.000000.
# Average reward for episode 200.000000.  Total average reward 184.000000.
# Average reward for episode 200.000000.  Total average reward 184.000000.
# Average reward for episode 200.000000.  Total average reward 184.000000.
# Average reward for episode 200.000000.  Total average reward 184.000000.
# Average reward for episode 200.000000.  Total average reward 184.000000.
# Average reward for episode 197.000000.  Total average reward 184.000000.
# Average reward for episode 200.000000.  Total average reward 184.000000.
# Average reward for episode 189.000000.  Total average reward 184.000000.
# Average reward for episode 197.000000.  Total average reward 185.000000.
# Average reward for episode 198.000000.  Total average reward 185.000000.
# Average reward for episode 187.000000.  Total average reward 185.000000.
# Average reward for episode 186.000000.  Total average reward 185.000000.
# Average reward for episode 194.000000.  Total average reward 185.000000.
# Average reward for episode 200.000000.  Total average reward 185.000000.
# Average reward for episode 200.000000.  Total average reward 185.000000.
# Average reward for episode 187.000000.  Total average reward 185.000000.
# Average reward for episode 190.000000.  Total average reward 185.000000.
# Average reward for episode 200.000000.  Total average reward 185.000000.
# Average reward for episode 189.000000.  Total average reward 185.000000.
# Average reward for episode 200.000000.  Total average reward 186.000000.
# Average reward for episode 194.000000.  Total average reward 186.000000.
# Average reward for episode 197.000000.  Total average reward 186.000000.
# Average reward for episode 195.000000.  Total average reward 186.000000.
# Average reward for episode 193.000000.  Total average reward 186.000000.
# Average reward for episode 192.000000.  Total average reward 186.000000.
# Average reward for episode 200.000000.  Total average reward 186.000000.
# Average reward for episode 194.000000.  Total average reward 186.000000.
# Average reward for episode 195.000000.  Total average reward 186.000000.
# Average reward for episode 200.000000.  Total average reward 186.000000.
# Average reward for episode 192.000000.  Total average reward 186.000000.
# Average reward for episode 191.000000.  Total average reward 186.000000.
# Average reward for episode 200.000000.  Total average reward 187.000000.
# Average reward for episode 200.000000.  Total average reward 187.000000.
# Average reward for episode 200.000000.  Total average reward 187.000000.
# Average reward for episode 200.000000.  Total average reward 187.000000.
# Average reward for episode 200.000000.  Total average reward 187.000000.
# Average reward for episode 200.000000.  Total average reward 187.000000.
# Average reward for episode 195.000000.  Total average reward 187.000000.
# Average reward for episode 193.000000.  Total average reward 187.000000.
# Average reward for episode 200.000000.  Total average reward 187.000000.
# Average reward for episode 200.000000.  Total average reward 188.000000.
# Average reward for episode 200.000000.  Total average reward 188.000000.
# Average reward for episode 200.000000.  Total average reward 188.000000.
# Average reward for episode 200.000000.  Total average reward 188.000000.
# Average reward for episode 200.000000.  Total average reward 188.000000.
# Average reward for episode 200.000000.  Total average reward 188.000000.
# Average reward for episode 200.000000.  Total average reward 188.000000.
# Average reward for episode 200.000000.  Total average reward 188.000000.
# Average reward for episode 200.000000.  Total average reward 189.000000.
# Average reward for episode 200.000000.  Total average reward 189.000000.
# Average reward for episode 200.000000.  Total average reward 189.000000.
# Average reward for episode 200.000000.  Total average reward 189.000000.
# Average reward for episode 200.000000.  Total average reward 189.000000.
# Average reward for episode 196.000000.  Total average reward 189.000000.
# Average reward for episode 200.000000.  Total average reward 189.000000.
# Average reward for episode 187.000000.  Total average reward 189.000000.
# Average reward for episode 200.000000.  Total average reward 189.000000.
# Average reward for episode 200.000000.  Total average reward 189.000000.
# Average reward for episode 200.000000.  Total average reward 189.000000.
# Average reward for episode 195.000000.  Total average reward 189.000000.
# Average reward for episode 185.000000.  Total average reward 189.000000.
# Average reward for episode 200.000000.  Total average reward 190.000000.
# Average reward for episode 188.000000.  Total average reward 190.000000.
# Average reward for episode 200.000000.  Total average reward 190.000000.
# Average reward for episode 200.000000.  Total average reward 190.000000.
# Average reward for episode 199.000000.  Total average reward 190.000000.
# Average reward for episode 194.000000.  Total average reward 190.000000.
# Average reward for episode 192.000000.  Total average reward 190.000000.
# Average reward for episode 198.000000.  Total average reward 190.000000.
# Average reward for episode 188.000000.  Total average reward 190.000000.
# Average reward for episode 200.000000.  Total average reward 190.000000.
# Average reward for episode 200.000000.  Total average reward 190.000000.
# Average reward for episode 200.000000.  Total average reward 190.000000.
# Average reward for episode 182.000000.  Total average reward 190.000000.
# Average reward for episode 198.000000.  Total average reward 190.000000.
# Average reward for episode 194.000000.  Total average reward 190.000000.
# Average reward for episode 187.000000.  Total average reward 190.000000.
# Average reward for episode 192.000000.  Total average reward 190.000000.
# Average reward for episode 173.000000.  Total average reward 190.000000.
# Average reward for episode 199.000000.  Total average reward 190.000000.
# Average reward for episode 188.000000.  Total average reward 190.000000.
# Average reward for episode 187.000000.  Total average reward 190.000000.
# Average reward for episode 183.000000.  Total average reward 190.000000.
# Average reward for episode 181.000000.  Total average reward 190.000000.
# Average reward for episode 197.000000.  Total average reward 190.000000.
# Average reward for episode 175.000000.  Total average reward 190.000000.
# Average reward for episode 200.000000.  Total average reward 190.000000.
# Average reward for episode 190.000000.  Total average reward 190.000000.
# Average reward for episode 194.000000.  Total average reward 190.000000.
# Average reward for episode 185.000000.  Total average reward 190.000000.
# Average reward for episode 200.000000.  Total average reward 190.000000.
# Average reward for episode 200.000000.  Total average reward 190.000000.
# Average reward for episode 199.000000.  Total average reward 190.000000.
# Average reward for episode 198.000000.  Total average reward 190.000000.
# Average reward for episode 200.000000.  Total average reward 190.000000.
# Average reward for episode 198.000000.  Total average reward 190.000000.
# Average reward for episode 187.000000.  Total average reward 190.000000.
# Average reward for episode 196.000000.  Total average reward 190.000000.
# Average reward for episode 200.000000.  Total average reward 191.000000.
# Average reward for episode 200.000000.  Total average reward 191.000000.
# Average reward for episode 200.000000.  Total average reward 191.000000.
# Average reward for episode 198.000000.  Total average reward 191.000000.
# Average reward for episode 191.000000.  Total average reward 191.000000.
# Average reward for episode 198.000000.  Total average reward 191.000000.
# Average reward for episode 186.000000.  Total average reward 191.000000.
# Average reward for episode 200.000000.  Total average reward 191.000000.
# Average reward for episode 200.000000.  Total average reward 191.000000.
# Average reward for episode 200.000000.  Total average reward 191.000000.
# Average reward for episode 188.000000.  Total average reward 191.000000.
# Average reward for episode 196.000000.  Total average reward 191.000000.
# Average reward for episode 200.000000.  Total average reward 191.000000.
# Average reward for episode 200.000000.  Total average reward 191.000000.
# Average reward for episode 200.000000.  Total average reward 191.000000.
# Average reward for episode 188.000000.  Total average reward 191.000000.
# Average reward for episode 198.000000.  Total average reward 191.000000.
# Average reward for episode 200.000000.  Total average reward 191.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 193.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 194.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 197.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 189.000000.  Total average reward 193.000000.
# Average reward for episode 160.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 187.000000.  Total average reward 192.000000.
# Average reward for episode 195.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 187.000000.  Total average reward 192.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 195.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 183.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 175.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 188.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 193.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 182.000000.  Total average reward 194.000000.
# Average reward for episode 199.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 197.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 192.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 186.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 194.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 189.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 199.000000.  Total average reward 195.000000.
# Average reward for episode 189.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# ...
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 195.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 191.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 185.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 187.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 191.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 189.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 184.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 192.000000.  Total average reward 196.000000.
# Average reward for episode 193.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 196.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 196.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 183.000000.  Total average reward 197.000000.
# Average reward for episode 192.000000.  Total average reward 197.000000.
# Average reward for episode 185.000000.  Total average reward 197.000000.
# Average reward for episode 194.000000.  Total average reward 197.000000.
# Average reward for episode 194.000000.  Total average reward 197.000000.
# Average reward for episode 199.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 194.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 187.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 197.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 179.000000.  Total average reward 197.000000.
# Average reward for episode 186.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 191.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 197.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 192.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 197.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.
# Average reward for episode 200.000000.  Total average reward 198.000000.

# %% [markdown]
# As you can see, the network not only does much better than random actions, but achieves the goal of 200 points per episode, thus solving the task!

# %%
episodic_average = []
total_average = []
with open("PG_rewards.txt") as f:
    for i in f.readlines():
        sample = i.split("  ")
        episodic_average.append(float(sample[0][27:-1]))#,sample[1][21]
        total_average.append(sample[1][20:])
# Out:
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  18.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  21.000000.
#
#  21.000000.
#
#  21.000000.
#
#  21.000000.
#
#  21.000000.
#
#  21.000000.
#
#  21.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  27.000000.
#
#  27.000000.
#
#  27.000000.
#
#  27.000000.
#
#  28.000000.
#
#  28.000000.
#
#  28.000000.
#
#  28.000000.
#
#  28.000000.
#
#  28.000000.
#
#  28.000000.
#
#  29.000000.
#
#  29.000000.
#
#  29.000000.
#
#  29.000000.
#
#  30.000000.
#
#  30.000000.
#
#  30.000000.
#
#  30.000000.
#
#  30.000000.
#
#  30.000000.
#
#  31.000000.
#
#  31.000000.
#
#  32.000000.
#
#  32.000000.
#
#  32.000000.
#
#  32.000000.
#
#  33.000000.
#
#  33.000000.
#
#  33.000000.
#
#  33.000000.
#
#  34.000000.
#
#  34.000000.
#
#  34.000000.
#
#  35.000000.
#
#  35.000000.
#
#  35.000000.
#
#  36.000000.
#
#  36.000000.
#
#  36.000000.
#
#  36.000000.
#
#  36.000000.
#
#  37.000000.
#
#  37.000000.
#
#  37.000000.
#
#  38.000000.
#
#  38.000000.
#
#  38.000000.
#
#  38.000000.
#
#  39.000000.
#
#  39.000000.
#
#  40.000000.
#
#  40.000000.
#
#  41.000000.
#
#  41.000000.
#
#  42.000000.
#
#  43.000000.
#
#  43.000000.
#
#  44.000000.
#
#  45.000000.
#
#  46.000000.
#
#  47.000000.
#
#  48.000000.
#
#  48.000000.
#
#  49.000000.
#
#  49.000000.
#
#  50.000000.
#
#  50.000000.
#
#  51.000000.
#
#  52.000000.
#
#  53.000000.
#
#  54.000000.
#
#  55.000000.
#
#  55.000000.
#
#  56.000000.
#
#  56.000000.
#
#  57.000000.
#
#  57.000000.
#
#  58.000000.
#
#  59.000000.
#
#  60.000000.
#
#  60.000000.
#
#  61.000000.
#
#  62.000000.
#
#  62.000000.
#
#  63.000000.
#
#  63.000000.
#
#  64.000000.
#
#  65.000000.
#
#  66.000000.
#
#  66.000000.
#
#  67.000000.
#
#  68.000000.
#
#  69.000000.
#
#  70.000000.
#
#  71.000000.
#
#  72.000000.
#
#  73.000000.
#
#  74.000000.
#
#  75.000000.
#
#  76.000000.
#
#  76.000000.
#
#  78.000000.
#
#  78.000000.
#
#  79.000000.
#
#  80.000000.
#
#  81.000000.
#
#  82.000000.
#
#  83.000000.
#
#  83.000000.
#
#  85.000000.
#
#  85.000000.
#
#  86.000000.
#
#  87.000000.
#
#  88.000000.
#
#  89.000000.
#
#  90.000000.
#
#  91.000000.
#
#  92.000000.
#
#  93.000000.
#
#  94.000000.
#
#  95.000000.
#
#  96.000000.
#
#  97.000000.
#
#  97.000000.
#
#  98.000000.
#
#  99.000000.
#
#  100.000000.
#
#  100.000000.
#
#  101.000000.
#
#  102.000000.
#
#  103.000000.
#
#  103.000000.
#
#  104.000000.
#
#  105.000000.
#
#  106.000000.
#
#  107.000000.
#
#  107.000000.
#
#  108.000000.
#
#  109.000000.
#
#  109.000000.
#
#  110.000000.
#
#  111.000000.
#
#  111.000000.
#
#  112.000000.
#
#  113.000000.
#
#  113.000000.
#
#  114.000000.
#
#  115.000000.
#
#  116.000000.
#
#  116.000000.
#
#  117.000000.
#
#  117.000000.
#
#  118.000000.
#
#  119.000000.
#
#  119.000000.
#
#  120.000000.
#
#  121.000000.
#
#  121.000000.
#
#  122.000000.
#
#  122.000000.
#
#  123.000000.
#
#  123.000000.
#
#  124.000000.
#
#  125.000000.
#
#  125.000000.
#
#  126.000000.
#
#  126.000000.
#
#  127.000000.
#
#  127.000000.
#
#  128.000000.
#
#  128.000000.
#
#  129.000000.
#
#  130.000000.
#
#  130.000000.
#
#  131.000000.
#
#  132.000000.
#
#  132.000000.
#
#  133.000000.
#
#  133.000000.
#
#  134.000000.
#
#  135.000000.
#
#  135.000000.
#
#  136.000000.
#
#  137.000000.
#
#  137.000000.
#
#  138.000000.
#
#  138.000000.
#
#  139.000000.
#
#  140.000000.
#
#  140.000000.
#
#  140.000000.
#
#  141.000000.
#
#  142.000000.
#
#  142.000000.
#
#  142.000000.
#
#  143.000000.
#
#  143.000000.
#
#  144.000000.
#
#  144.000000.
#
#  145.000000.
#
#  145.000000.
#
#  146.000000.
#
#  146.000000.
#
#  147.000000.
#
#  147.000000.
#
#  148.000000.
#
#  148.000000.
#
#  148.000000.
#
#  149.000000.
#
#  149.000000.
#
#  150.000000.
#
#  150.000000.
#
#  150.000000.
#
#  151.000000.
#
#  151.000000.
#
#  152.000000.
#
#  152.000000.
#
#  153.000000.
#
#  153.000000.
#
#  153.000000.
#
#  153.000000.
#
#  154.000000.
#
#  154.000000.
#
#  155.000000.
#
#  155.000000.
#
#  156.000000.
#
#  156.000000.
#
#  156.000000.
#
#  157.000000.
#
#  157.000000.
#
#  158.000000.
#
#  158.000000.
#
#  158.000000.
#
#  159.000000.
#
#  159.000000.
#
#  159.000000.
#
#  160.000000.
#
#  160.000000.
#
#  161.000000.
#
#  161.000000.
#
#  161.000000.
#
#  162.000000.
#
#  162.000000.
#
#  162.000000.
#
#  162.000000.
#
#  163.000000.
#
#  163.000000.
#
#  163.000000.
#
#  164.000000.
#
#  164.000000.
#
#  164.000000.
#
#  165.000000.
#
#  165.000000.
#
#  165.000000.
#
#  166.000000.
#
#  166.000000.
#
#  166.000000.
#
#  166.000000.
#
#  167.000000.
#
#  167.000000.
#
#  167.000000.
#
#  168.000000.
#
#  168.000000.
#
#  168.000000.
#
#  168.000000.
#
#  169.000000.
#
#  169.000000.
#
#  169.000000.
#
#  169.000000.
#
#  170.000000.
#
#  170.000000.
#
#  170.000000.
#
#  171.000000.
#
#  171.000000.
#
#  171.000000.
#
#  171.000000.
#
#  172.000000.
#
#  172.000000.
#
#  172.000000.
#
#  172.000000.
#
#  173.000000.
#
#  173.000000.
#
#  173.000000.
#
#  173.000000.
#
#  174.000000.
#
#  174.000000.
#
#  174.000000.
#
#  174.000000.
#
#  175.000000.
#
#  175.000000.
#
#  175.000000.
#
#  175.000000.
#
#  176.000000.
#
#  176.000000.
#
#  176.000000.
#
#  176.000000.
#
#  177.000000.
#
#  177.000000.
#
#  177.000000.
#
#  177.000000.
#
#  177.000000.
#
#  178.000000.
#
#  178.000000.
#
#  178.000000.
#
#  178.000000.
#
#  178.000000.
#
#  179.000000.
#
#  179.000000.
#
#  179.000000.
#
#  179.000000.
#
#  180.000000.
#
#  180.000000.
#
#  180.000000.
#
#  180.000000.
#
#  180.000000.
#
#  180.000000.
#
#  181.000000.
#
#  181.000000.
#
#  181.000000.
#
#  181.000000.
#
#  181.000000.
#
#  182.000000.
#
#  182.000000.
#
#  182.000000.
#
#  182.000000.
#
#  182.000000.
#
#  182.000000.
#
#  182.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  184.000000.
#
#  184.000000.
#
#  184.000000.
#
#  184.000000.
#
#  184.000000.
#
#  184.000000.
#
#  184.000000.
#
#  184.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  188.000000.
#
#  188.000000.
#
#  188.000000.
#
#  188.000000.
#
#  188.000000.
#
#  188.000000.
#
#  188.000000.
#
#  188.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  193.000000.
#
#  192.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  197.000000.
#
#  197.000000.
#
#  198.000000.
#
#  197.000000.
#
#  198.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  195.000000.
#
#  196.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  198.000000.
#
#  198.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  197.000000.
#
#  197.000000.
#
#  196.000000.
#
#  197.000000.
#
#  197.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
