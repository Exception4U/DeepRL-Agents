# %% [markdown]
# # Simple Reinforcement Learning in Tensorflow Part 2: Policy Gradient Method
# This tutorial contains a simple example of how to build a policy-gradient based agent that can solve the CartPole problem. For more information, see this [Medium post](https://medium.com/@awjuliani/super-simple-reinforcement-learning-tutorial-part-2-ded33892c724#.mtwpvfi8b).
#
# For more Reinforcement Learning algorithms, including DQN and Model-based learning in Tensorflow, see my Github repo, [DeepRL-Agents](https://github.com/awjuliani/DeepRL-Agents).
#
# Parts of this tutorial are based on code by [Andrej Karpathy](https://gist.github.com/karpathy/a4166c7fe253700972fcbc77e4ea32c5) and [korymath](https://gym.openai.com/evaluations/eval_a0aVJrGSyW892vBM04HQA).

# %%
from __future__ import division

import numpy as np
try:
    import cPickle as pickle
except:
    import pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math

try:
    xrange = xrange
except:
    xrange = range

# %% [markdown]
# ### Loading the CartPole Environment
# If you don't already have the OpenAI gym installed, use  `pip install gym` to grab it.

# %%
import gym
env = gym.make('CartPole-v0')

# %% [markdown]
# What happens if we try running the environment with random actions? How well do we do? (Hint: not so well.)

# %%
env.reset()
random_episodes = 0
reward_sum = 0
while random_episodes < 10:
    env.render()
    observation, reward, done, _ = env.step(np.random.randint(0,2))
    reward_sum += reward
    if done:
        random_episodes += 1
        print("Reward for this episode was:",reward_sum)
        reward_sum = 0
        env.reset()
# Out:
# Reward for this episode was: 42.0
# Reward for this episode was: 16.0
# Reward for this episode was: 26.0
# Reward for this episode was: 17.0
# Reward for this episode was: 39.0
# Reward for this episode was: 10.0
# Reward for this episode was: 19.0
# Reward for this episode was: 17.0
# Reward for this episode was: 18.0
# Reward for this episode was: 21.0

# %% [markdown]
# The goal of the task is to achieve a reward of 200 per episode. For every step the agent keeps the pole in the air, the agent recieves a +1 reward. By randomly choosing actions, our reward for each episode is only a couple dozen. Let's make that better with RL!

# %% [markdown]
# ### Setting up our Neural Network agent
# This time we will be using a Policy neural network that takes observations, passes them through a single hidden layer, and then produces a probability of choosing a left/right movement. To learn more about this network, see [Andrej Karpathy's blog on Policy Gradient networks](http://karpathy.github.io/2016/05/31/rl/).

# %%
# hyperparameters
H = 10 # number of hidden layer neurons
batch_size = 5 # every how many episodes to do a param update?
learning_rate = 1e-2 # feel free to play with this to train faster or more stably.
gamma = 0.99 # discount factor for reward

D = 4 # input dimensionality

# %%
tf.reset_default_graph()

#This defines the network as it goes from taking an observation of the environment to 
#giving a probability of chosing to the action of moving left or right.
observations = tf.placeholder(tf.float32, [None,D] , name="input_x")
W1 = tf.get_variable("W1", shape=[D, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

#From here we define the parts of the network needed for learning a good policy.
tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")

# The loss function. This sends the weights in the direction of making actions 
# that gave good advantage (reward over time) more likely, and actions that didn't less likely.
loglik = tf.log(input_y*(input_y - probability) + (1 - input_y)*(input_y + probability))
loss = -tf.reduce_mean(loglik * advantages) 
newGrads = tf.gradients(loss,tvars)

# Once we have collected a series of gradients from multiple episodes, we apply them.
# We don't just apply gradeients after every episode in order to account for noise in the reward signal.
adam = tf.train.AdamOptimizer(learning_rate=learning_rate) # Our optimizer
W1Grad = tf.placeholder(tf.float32,name="batch_grad1") # Placeholders to send the final gradients through when we update.
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %% [markdown]
# ### Advantage function
# This function allows us to weigh the rewards our agent recieves. In the context of the Cart-Pole task, we want actions that kept the pole in the air a long time to have a large reward, and actions that contributed to the pole falling to have a decreased or negative reward. We do this by weighing the rewards from the end of the episode, with actions at the end being seen as negative, since they likely contributed to the pole falling, and the episode ending. Likewise, early actions are seen as more positive, since they weren't responsible for the pole falling.

# %%
def discount_rewards(r):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_add = 0
    for t in reversed(xrange(0, r.size)):
        running_add = running_add * gamma + r[t]
        discounted_r[t] = running_add
    return discounted_r

# %% [markdown]
# ### Running the Agent and Environment

# %% [markdown]
# Here we run the neural network agent, and have it act in the CartPole environment.

# %%
xs,hs,dlogps,drs,ys,tfps = [],[],[],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
total_episodes = 10000
init = tf.global_variables_initializer()

#tf settings for incremental memory
config = tf.ConfigProto()
config.gpu_options.allow_growth = True



# Launch the graph
sess = tf.Session(config=config)
rendering = False
sess.run(init)
observation = env.reset() # Obtain an initial observation of the environment

# Reset the gradient placeholder. We will collect gradients in 
# gradBuffer until we are ready to update our policy network. 
gradBuffer = sess.run(tvars)
for ix,grad in enumerate(gradBuffer):
    gradBuffer[ix] = grad * 0

while episode_number <= total_episodes:
    # Rendering the environment slows things down, 
    # so let's only look at it once our agent is doing a good job.
    if reward_sum/batch_size > 100 or rendering == True : 
#             env.render()
        rendering = True

    # Make sure the observation is in a shape the network can handle.
    x = np.reshape(observation,[1,D])

    # Run the policy network and get an action to take. 
    tfprob = sess.run(probability,feed_dict={observations: x})
    action = 1 if np.random.uniform() < tfprob else 0

    xs.append(x) # observation
    y = 1 if action == 0 else 0 # a "fake label"
    ys.append(y)

    # step the environment and get new measurements
    observation, reward, done, info = env.step(action)
    reward_sum += reward

    drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

    if done: 
        episode_number += 1
        # stack together all inputs, hidden states, action gradients, and rewards for this episode
        epx = np.vstack(xs)
        epy = np.vstack(ys)
        epr = np.vstack(drs)
        tfp = tfps
        xs,hs,dlogps,drs,ys,tfps = [],[],[],[],[],[] # reset array memory

        # compute the discounted reward backwards through time
        discounted_epr = discount_rewards(epr)
        # size the rewards to be unit normal (helps control the gradient estimator variance)
        discounted_epr -= np.mean(discounted_epr)
        discounted_epr //= np.std(discounted_epr)

        # Get the gradient for this episode, and save it in the gradBuffer
        tGrad = sess.run(newGrads,feed_dict={observations: epx, input_y: epy, advantages: discounted_epr})
        for ix,grad in enumerate(tGrad):
            gradBuffer[ix] += grad

        # If we have completed enough episodes, then update the policy network with our gradients.
        if episode_number % batch_size == 0: 
            sess.run(updateGrads,feed_dict={W1Grad: gradBuffer[0],W2Grad:gradBuffer[1]})
            for ix,grad in enumerate(gradBuffer):
                gradBuffer[ix] = grad * 0

            # Give a summary of how well our network is doing for each batch of episodes.
            running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
            print('Average reward for episode %f.  Total average reward %f.' % (reward_sum//batch_size, running_reward//batch_size))
            print(episode_number)
            if reward_sum//batch_size > 200: 
                print("Task solved in",episode_number,'episodes!')
                break

            reward_sum = 0

        observation = env.reset()
#         #weights saver
#         saver = tf.train.Saver()
#         saver_path = saver.save(sess,"./PG_cartpole_weights.ckpt")
sess.close()
print(episode_number,'Episodes completed.')
# Out:
# Average reward for episode 11.000000.  Total average reward 11.000000.
# 5
# Average reward for episode 21.000000.  Total average reward 11.000000.
# 10
# Average reward for episode 21.000000.  Total average reward 11.000000.
# 15
# Average reward for episode 20.000000.  Total average reward 11.000000.
# 20
# Average reward for episode 31.000000.  Total average reward 12.000000.
# 25
# Average reward for episode 16.000000.  Total average reward 12.000000.
# 30
# Average reward for episode 23.000000.  Total average reward 12.000000.
# 35
# Average reward for episode 20.000000.  Total average reward 12.000000.
# 40
# Average reward for episode 18.000000.  Total average reward 12.000000.
# 45
# Average reward for episode 37.000000.  Total average reward 12.000000.
# 50
# Average reward for episode 24.000000.  Total average reward 12.000000.
# 55
# Average reward for episode 18.000000.  Total average reward 12.000000.
# 60
# Average reward for episode 25.000000.  Total average reward 12.000000.
# 65
# Average reward for episode 32.000000.  Total average reward 13.000000.
# 70
# Average reward for episode 15.000000.  Total average reward 13.000000.
# 75
# Average reward for episode 28.000000.  Total average reward 13.000000.
# 80
# Average reward for episode 21.000000.  Total average reward 13.000000.
# 85
# Average reward for episode 19.000000.  Total average reward 13.000000.
# 90
# Average reward for episode 22.000000.  Total average reward 13.000000.
# 95
# Average reward for episode 17.000000.  Total average reward 13.000000.
# 100
# Average reward for episode 25.000000.  Total average reward 13.000000.
# 105
# Average reward for episode 29.000000.  Total average reward 13.000000.
# 110
# Average reward for episode 27.000000.  Total average reward 13.000000.
# 115
# Average reward for episode 40.000000.  Total average reward 14.000000.
# 120
# Average reward for episode 17.000000.  Total average reward 14.000000.
# 125
# Average reward for episode 25.000000.  Total average reward 14.000000.
# 130
# Average reward for episode 34.000000.  Total average reward 14.000000.
# 135
# Average reward for episode 25.000000.  Total average reward 14.000000.
# 140
# Average reward for episode 34.000000.  Total average reward 14.000000.
# 145
# Average reward for episode 26.000000.  Total average reward 15.000000.
# 150
# Average reward for episode 16.000000.  Total average reward 15.000000.
# 155
# Average reward for episode 37.000000.  Total average reward 15.000000.
# 160
# Average reward for episode 27.000000.  Total average reward 15.000000.
# 165
# Average reward for episode 27.000000.  Total average reward 15.000000.
# 170
# Average reward for episode 19.000000.  Total average reward 15.000000.
# 175
# Average reward for episode 41.000000.  Total average reward 15.000000.
# 180
# Average reward for episode 29.000000.  Total average reward 15.000000.
# 185
# Average reward for episode 29.000000.  Total average reward 16.000000.
# 190
# Average reward for episode 25.000000.  Total average reward 16.000000.
# 195
# Average reward for episode 30.000000.  Total average reward 16.000000.
# 200
# Average reward for episode 28.000000.  Total average reward 16.000000.
# 205
# Average reward for episode 35.000000.  Total average reward 16.000000.
# 210
# Average reward for episode 55.000000.  Total average reward 16.000000.
# 215
# Average reward for episode 48.000000.  Total average reward 17.000000.
# 220
# Average reward for episode 39.000000.  Total average reward 17.000000.
# 225
# Average reward for episode 39.000000.  Total average reward 17.000000.
# 230
# Average reward for episode 70.000000.  Total average reward 18.000000.
# 235
# Average reward for episode 70.000000.  Total average reward 18.000000.
# 240
# Average reward for episode 31.000000.  Total average reward 18.000000.
# 245
# Average reward for episode 39.000000.  Total average reward 19.000000.
# 250
# Average reward for episode 54.000000.  Total average reward 19.000000.
# 255
# Average reward for episode 51.000000.  Total average reward 19.000000.
# 260
# Average reward for episode 30.000000.  Total average reward 19.000000.
# 265
# Average reward for episode 41.000000.  Total average reward 20.000000.
# 270
# Average reward for episode 40.000000.  Total average reward 20.000000.
# 275
# Average reward for episode 56.000000.  Total average reward 20.000000.
# 280
# Average reward for episode 28.000000.  Total average reward 20.000000.
# 285
# Average reward for episode 50.000000.  Total average reward 21.000000.
# 290
# Average reward for episode 54.000000.  Total average reward 21.000000.
# 295
# Average reward for episode 56.000000.  Total average reward 21.000000.
# 300
# Average reward for episode 48.000000.  Total average reward 22.000000.
# 305
# Average reward for episode 71.000000.  Total average reward 22.000000.
# 310
# Average reward for episode 51.000000.  Total average reward 22.000000.
# 315
# Average reward for episode 29.000000.  Total average reward 22.000000.
# 320
# Average reward for episode 47.000000.  Total average reward 23.000000.
# 325
# Average reward for episode 46.000000.  Total average reward 23.000000.
# 330
# Average reward for episode 72.000000.  Total average reward 23.000000.
# 335
# Average reward for episode 46.000000.  Total average reward 24.000000.
# 340
# Average reward for episode 48.000000.  Total average reward 24.000000.
# 345
# Average reward for episode 42.000000.  Total average reward 24.000000.
# 350
# Average reward for episode 33.000000.  Total average reward 24.000000.
# 355
# Average reward for episode 59.000000.  Total average reward 24.000000.
# 360
# Average reward for episode 59.000000.  Total average reward 25.000000.
# 365
# Average reward for episode 39.000000.  Total average reward 25.000000.
# 370
# Average reward for episode 51.000000.  Total average reward 25.000000.
# 375
# Average reward for episode 63.000000.  Total average reward 26.000000.
# 380
# Average reward for episode 95.000000.  Total average reward 26.000000.
# 385
# Average reward for episode 74.000000.  Total average reward 27.000000.
# 390
# Average reward for episode 64.000000.  Total average reward 27.000000.
# 395
# Average reward for episode 62.000000.  Total average reward 27.000000.
# 400
# Average reward for episode 47.000000.  Total average reward 28.000000.
# 405
# Average reward for episode 41.000000.  Total average reward 28.000000.
# 410
# Average reward for episode 60.000000.  Total average reward 28.000000.
# 415
# Average reward for episode 41.000000.  Total average reward 28.000000.
# 420
# Average reward for episode 31.000000.  Total average reward 28.000000.
# 425
# Average reward for episode 85.000000.  Total average reward 29.000000.
# 430
# Average reward for episode 25.000000.  Total average reward 29.000000.
# 435
# Average reward for episode 30.000000.  Total average reward 29.000000.
# 440
# Average reward for episode 51.000000.  Total average reward 29.000000.
# 445
# Average reward for episode 55.000000.  Total average reward 29.000000.
# 450
# Average reward for episode 74.000000.  Total average reward 30.000000.
# 455
# Average reward for episode 51.000000.  Total average reward 30.000000.
# 460
# Average reward for episode 62.000000.  Total average reward 30.000000.
# 465
# Average reward for episode 100.000000.  Total average reward 31.000000.
# 470
# Average reward for episode 71.000000.  Total average reward 31.000000.
# 475
# Average reward for episode 119.000000.  Total average reward 32.000000.
# 480
# Average reward for episode 102.000000.  Total average reward 33.000000.
# 485
# Average reward for episode 71.000000.  Total average reward 33.000000.
# 490
# Average reward for episode 121.000000.  Total average reward 34.000000.
# 495
# Average reward for episode 48.000000.  Total average reward 34.000000.
# 500
# Average reward for episode 116.000000.  Total average reward 35.000000.
# 505
# Average reward for episode 106.000000.  Total average reward 36.000000.
# 510
# Average reward for episode 51.000000.  Total average reward 36.000000.
# 515
# Average reward for episode 57.000000.  Total average reward 36.000000.
# 520
# Average reward for episode 59.000000.  Total average reward 36.000000.
# 525
# Average reward for episode 56.000000.  Total average reward 37.000000.
# 530
# Average reward for episode 138.000000.  Total average reward 38.000000.
# 535
# Average reward for episode 77.000000.  Total average reward 38.000000.
# 540
# Average reward for episode 36.000000.  Total average reward 38.000000.
# 545
# Average reward for episode 77.000000.  Total average reward 38.000000.
# 550
# Average reward for episode 66.000000.  Total average reward 39.000000.
# 555
# Average reward for episode 59.000000.  Total average reward 39.000000.
# 560
# Average reward for episode 43.000000.  Total average reward 39.000000.
# 565
# Average reward for episode 67.000000.  Total average reward 39.000000.
# 570
# Average reward for episode 85.000000.  Total average reward 40.000000.
# 575
# Average reward for episode 92.000000.  Total average reward 40.000000.
# 580
# Average reward for episode 115.000000.  Total average reward 41.000000.
# 585
# Average reward for episode 99.000000.  Total average reward 41.000000.
# 590
# Average reward for episode 69.000000.  Total average reward 42.000000.
# 595
# Average reward for episode 98.000000.  Total average reward 42.000000.
# 600
# Average reward for episode 80.000000.  Total average reward 43.000000.
# 605
# Average reward for episode 44.000000.  Total average reward 43.000000.
# 610
# Average reward for episode 54.000000.  Total average reward 43.000000.
# 615
# Average reward for episode 74.000000.  Total average reward 43.000000.
# 620
# Average reward for episode 81.000000.  Total average reward 43.000000.
# 625
# Average reward for episode 85.000000.  Total average reward 44.000000.
# 630
# Average reward for episode 70.000000.  Total average reward 44.000000.
# 635
# Average reward for episode 72.000000.  Total average reward 44.000000.
# 640
# Average reward for episode 67.000000.  Total average reward 45.000000.
# 645
# Average reward for episode 97.000000.  Total average reward 45.000000.
# 650
# Average reward for episode 67.000000.  Total average reward 45.000000.
# 655
# Average reward for episode 101.000000.  Total average reward 46.000000.
# 660
# Average reward for episode 65.000000.  Total average reward 46.000000.
# 665
# Average reward for episode 136.000000.  Total average reward 47.000000.
# 670
# Average reward for episode 82.000000.  Total average reward 47.000000.
# 675
# Average reward for episode 116.000000.  Total average reward 48.000000.
# 680
# Average reward for episode 69.000000.  Total average reward 48.000000.
# 685
# Average reward for episode 77.000000.  Total average reward 49.000000.
# 690
# Average reward for episode 79.000000.  Total average reward 49.000000.
# 695
# Average reward for episode 50.000000.  Total average reward 49.000000.
# 700
# Average reward for episode 113.000000.  Total average reward 50.000000.
# 705
# Average reward for episode 123.000000.  Total average reward 50.000000.
# 710
# Average reward for episode 63.000000.  Total average reward 50.000000.
# 715
# Average reward for episode 119.000000.  Total average reward 51.000000.
# 720
# Average reward for episode 78.000000.  Total average reward 51.000000.
# 725
# Average reward for episode 67.000000.  Total average reward 52.000000.
# 730
# Average reward for episode 67.000000.  Total average reward 52.000000.
# 735
# Average reward for episode 86.000000.  Total average reward 52.000000.
# 740
# Average reward for episode 91.000000.  Total average reward 52.000000.
# 745
# Average reward for episode 94.000000.  Total average reward 53.000000.
# 750
# Average reward for episode 66.000000.  Total average reward 53.000000.
# 755
# Average reward for episode 114.000000.  Total average reward 54.000000.
# 760
# Average reward for episode 91.000000.  Total average reward 54.000000.
# 765
# Average reward for episode 84.000000.  Total average reward 54.000000.
# 770
# Average reward for episode 103.000000.  Total average reward 55.000000.
# 775
# Average reward for episode 71.000000.  Total average reward 55.000000.
# 780
# Average reward for episode 75.000000.  Total average reward 55.000000.
# 785
# Average reward for episode 144.000000.  Total average reward 56.000000.
# 790
# Average reward for episode 85.000000.  Total average reward 56.000000.
# 795
# Average reward for episode 96.000000.  Total average reward 57.000000.
# 800
# Average reward for episode 84.000000.  Total average reward 57.000000.
# 805
# Average reward for episode 65.000000.  Total average reward 57.000000.
# 810
# Average reward for episode 109.000000.  Total average reward 58.000000.
# 815
# Average reward for episode 139.000000.  Total average reward 58.000000.
# 820
# Average reward for episode 66.000000.  Total average reward 58.000000.
# 825
# Average reward for episode 154.000000.  Total average reward 59.000000.
# 830
# Average reward for episode 76.000000.  Total average reward 60.000000.
# 835
# Average reward for episode 77.000000.  Total average reward 60.000000.
# 840
# Average reward for episode 130.000000.  Total average reward 60.000000.
# 845
# Average reward for episode 104.000000.  Total average reward 61.000000.
# 850
# Average reward for episode 81.000000.  Total average reward 61.000000.
# 855
# Average reward for episode 110.000000.  Total average reward 62.000000.
# 860
# Average reward for episode 107.000000.  Total average reward 62.000000.
# 865
# Average reward for episode 68.000000.  Total average reward 62.000000.
# 870
# Average reward for episode 120.000000.  Total average reward 63.000000.
# 875
# Average reward for episode 141.000000.  Total average reward 63.000000.
# 880
# Average reward for episode 99.000000.  Total average reward 64.000000.
# 885
# Average reward for episode 108.000000.  Total average reward 64.000000.
# 890
# Average reward for episode 136.000000.  Total average reward 65.000000.
# 895
# Average reward for episode 162.000000.  Total average reward 66.000000.
# 900
# Average reward for episode 125.000000.  Total average reward 66.000000.
# 905
# Average reward for episode 101.000000.  Total average reward 67.000000.
# 910
# Average reward for episode 135.000000.  Total average reward 68.000000.
# 915
# Average reward for episode 111.000000.  Total average reward 68.000000.
# 920
# Average reward for episode 95.000000.  Total average reward 68.000000.
# 925
# Average reward for episode 90.000000.  Total average reward 68.000000.
# 930
# Average reward for episode 100.000000.  Total average reward 69.000000.
# 935
# Average reward for episode 81.000000.  Total average reward 69.000000.
# 940
# Average reward for episode 115.000000.  Total average reward 69.000000.
# 945
# Average reward for episode 161.000000.  Total average reward 70.000000.
# 950
# Average reward for episode 197.000000.  Total average reward 72.000000.
# 955
# Average reward for episode 115.000000.  Total average reward 72.000000.
# 960
# Average reward for episode 144.000000.  Total average reward 73.000000.
# 965
# Average reward for episode 116.000000.  Total average reward 73.000000.
# 970
# Average reward for episode 110.000000.  Total average reward 73.000000.
# 975
# Average reward for episode 171.000000.  Total average reward 74.000000.
# 980
# Average reward for episode 177.000000.  Total average reward 75.000000.
# 985
# Average reward for episode 135.000000.  Total average reward 76.000000.
# 990
# Average reward for episode 116.000000.  Total average reward 76.000000.
# 995
# Average reward for episode 125.000000.  Total average reward 77.000000.
# 1000
# Average reward for episode 112.000000.  Total average reward 77.000000.
# 1005
# Average reward for episode 191.000000.  Total average reward 78.000000.
# 1010
# Average reward for episode 96.000000.  Total average reward 79.000000.
# 1015
# Average reward for episode 116.000000.  Total average reward 79.000000.
# 1020
# Average reward for episode 145.000000.  Total average reward 80.000000.
# 1025
# Average reward for episode 98.000000.  Total average reward 80.000000.
# 1030
# Average reward for episode 145.000000.  Total average reward 80.000000.
# 1035
# Average reward for episode 141.000000.  Total average reward 81.000000.
# 1040
# Average reward for episode 113.000000.  Total average reward 81.000000.
# 1045
# Average reward for episode 112.000000.  Total average reward 82.000000.
# 1050
# Average reward for episode 152.000000.  Total average reward 82.000000.
# 1055
# Average reward for episode 135.000000.  Total average reward 83.000000.
# 1060
# Average reward for episode 171.000000.  Total average reward 84.000000.
# 1065
# Average reward for episode 140.000000.  Total average reward 84.000000.
# 1070
# Average reward for episode 81.000000.  Total average reward 84.000000.
# 1075
# Average reward for episode 136.000000.  Total average reward 85.000000.
# 1080
# Average reward for episode 136.000000.  Total average reward 85.000000.
# 1085
# Average reward for episode 103.000000.  Total average reward 86.000000.
# 1090
# Average reward for episode 110.000000.  Total average reward 86.000000.
# 1095
# Average reward for episode 139.000000.  Total average reward 86.000000.
# 1100
# Average reward for episode 126.000000.  Total average reward 87.000000.
# 1105
# Average reward for episode 143.000000.  Total average reward 87.000000.
# 1110
# Average reward for episode 115.000000.  Total average reward 88.000000.
# 1115
# Average reward for episode 110.000000.  Total average reward 88.000000.
# 1120
# Average reward for episode 156.000000.  Total average reward 88.000000.
# 1125
# Average reward for episode 142.000000.  Total average reward 89.000000.
# 1130
# Average reward for episode 126.000000.  Total average reward 89.000000.
# 1135
# Average reward for episode 145.000000.  Total average reward 90.000000.
# 1140
# Average reward for episode 143.000000.  Total average reward 90.000000.
# 1145
# Average reward for episode 147.000000.  Total average reward 91.000000.
# 1150
# Average reward for episode 122.000000.  Total average reward 91.000000.
# 1155
# Average reward for episode 162.000000.  Total average reward 92.000000.
# 1160
# Average reward for episode 167.000000.  Total average reward 93.000000.
# 1165
# Average reward for episode 123.000000.  Total average reward 93.000000.
# 1170
# Average reward for episode 166.000000.  Total average reward 94.000000.
# 1175
# Average reward for episode 196.000000.  Total average reward 95.000000.
# 1180
# Average reward for episode 151.000000.  Total average reward 95.000000.
# 1185
# Average reward for episode 114.000000.  Total average reward 96.000000.
# 1190
# Average reward for episode 196.000000.  Total average reward 97.000000.
# 1195
# Average reward for episode 175.000000.  Total average reward 97.000000.
# 1200
# Average reward for episode 173.000000.  Total average reward 98.000000.
# 1205
# Average reward for episode 155.000000.  Total average reward 99.000000.
# 1210
# Average reward for episode 185.000000.  Total average reward 100.000000.
# 1215
# Average reward for episode 168.000000.  Total average reward 100.000000.
# 1220
# Average reward for episode 179.000000.  Total average reward 101.000000.
# 1225
# Average reward for episode 194.000000.  Total average reward 102.000000.
# 1230
# Average reward for episode 197.000000.  Total average reward 103.000000.
# 1235
# Average reward for episode 176.000000.  Total average reward 104.000000.
# 1240
# Average reward for episode 186.000000.  Total average reward 104.000000.
# 1245
# Average reward for episode 129.000000.  Total average reward 105.000000.
# 1250
# Average reward for episode 160.000000.  Total average reward 105.000000.
# 1255
# Average reward for episode 179.000000.  Total average reward 106.000000.
# 1260
# Average reward for episode 181.000000.  Total average reward 107.000000.
# 1265
# Average reward for episode 180.000000.  Total average reward 107.000000.
# 1270
# Average reward for episode 148.000000.  Total average reward 108.000000.
# 1275
# Average reward for episode 172.000000.  Total average reward 109.000000.
# 1280
# Average reward for episode 197.000000.  Total average reward 109.000000.
# 1285
# Average reward for episode 195.000000.  Total average reward 110.000000.
# 1290
# Average reward for episode 141.000000.  Total average reward 111.000000.
# 1295
# Average reward for episode 145.000000.  Total average reward 111.000000.
# 1300
# Average reward for episode 180.000000.  Total average reward 112.000000.
# 1305
# Average reward for episode 163.000000.  Total average reward 112.000000.
# 1310
# Average reward for episode 180.000000.  Total average reward 113.000000.
# 1315
# Average reward for episode 146.000000.  Total average reward 113.000000.
# 1320
# Average reward for episode 191.000000.  Total average reward 114.000000.
# 1325
# Average reward for episode 185.000000.  Total average reward 115.000000.
# 1330
# Average reward for episode 183.000000.  Total average reward 115.000000.
# 1335
# Average reward for episode 200.000000.  Total average reward 116.000000.
# 1340
# Average reward for episode 177.000000.  Total average reward 117.000000.
# 1345
# Average reward for episode 133.000000.  Total average reward 117.000000.
# 1350
# Average reward for episode 181.000000.  Total average reward 118.000000.
# 1355
# Average reward for episode 192.000000.  Total average reward 118.000000.
# 1360
# Average reward for episode 176.000000.  Total average reward 119.000000.
# 1365
# Average reward for episode 200.000000.  Total average reward 120.000000.
# 1370
# Average reward for episode 197.000000.  Total average reward 120.000000.
# 1375
# Average reward for episode 159.000000.  Total average reward 121.000000.
# 1380
# Average reward for episode 200.000000.  Total average reward 122.000000.
# 1385
# Average reward for episode 179.000000.  Total average reward 122.000000.
# 1390
# Average reward for episode 127.000000.  Total average reward 122.000000.
# 1395
# Average reward for episode 122.000000.  Total average reward 122.000000.
# 1400
# Average reward for episode 155.000000.  Total average reward 123.000000.
# 1405
# Average reward for episode 129.000000.  Total average reward 123.000000.
# 1410
# Average reward for episode 176.000000.  Total average reward 123.000000.
# 1415
# Average reward for episode 137.000000.  Total average reward 123.000000.
# 1420
# Average reward for episode 174.000000.  Total average reward 124.000000.
# 1425
# Average reward for episode 200.000000.  Total average reward 125.000000.
# 1430
# Average reward for episode 189.000000.  Total average reward 125.000000.
# 1435
# Average reward for episode 144.000000.  Total average reward 125.000000.
# 1440
# Average reward for episode 132.000000.  Total average reward 125.000000.
# 1445
# Average reward for episode 167.000000.  Total average reward 126.000000.
# 1450
# Average reward for episode 171.000000.  Total average reward 126.000000.
# 1455
# Average reward for episode 199.000000.  Total average reward 127.000000.
# 1460
# Average reward for episode 187.000000.  Total average reward 128.000000.
# 1465
# Average reward for episode 162.000000.  Total average reward 128.000000.
# 1470
# Average reward for episode 193.000000.  Total average reward 129.000000.
# 1475
# Average reward for episode 180.000000.  Total average reward 129.000000.
# 1480
# Average reward for episode 188.000000.  Total average reward 130.000000.
# 1485
# Average reward for episode 146.000000.  Total average reward 130.000000.
# 1490
# Average reward for episode 163.000000.  Total average reward 130.000000.
# 1495
# Average reward for episode 181.000000.  Total average reward 131.000000.
# 1500
# Average reward for episode 145.000000.  Total average reward 131.000000.
# 1505
# Average reward for episode 186.000000.  Total average reward 131.000000.
# 1510
# Average reward for episode 178.000000.  Total average reward 132.000000.
# 1515
# Average reward for episode 146.000000.  Total average reward 132.000000.
# 1520
# Average reward for episode 159.000000.  Total average reward 132.000000.
# 1525
# Average reward for episode 182.000000.  Total average reward 133.000000.
# 1530
# Average reward for episode 166.000000.  Total average reward 133.000000.
# 1535
# Average reward for episode 127.000000.  Total average reward 133.000000.
# 1540
# Average reward for episode 200.000000.  Total average reward 134.000000.
# 1545
# Average reward for episode 197.000000.  Total average reward 134.000000.
# 1550
# Average reward for episode 159.000000.  Total average reward 135.000000.
# 1555
# Average reward for episode 200.000000.  Total average reward 135.000000.
# 1560
# Average reward for episode 165.000000.  Total average reward 136.000000.
# 1565
# Average reward for episode 170.000000.  Total average reward 136.000000.
# 1570
# Average reward for episode 186.000000.  Total average reward 136.000000.
# 1575
# Average reward for episode 181.000000.  Total average reward 137.000000.
# 1580
# Average reward for episode 166.000000.  Total average reward 137.000000.
# 1585
# Average reward for episode 185.000000.  Total average reward 138.000000.
# 1590
# Average reward for episode 200.000000.  Total average reward 138.000000.
# 1595
# Average reward for episode 184.000000.  Total average reward 139.000000.
# 1600
# Average reward for episode 188.000000.  Total average reward 139.000000.
# 1605
# Average reward for episode 185.000000.  Total average reward 140.000000.
# 1610
# Average reward for episode 176.000000.  Total average reward 140.000000.
# 1615
# Average reward for episode 149.000000.  Total average reward 140.000000.
# 1620
# Average reward for episode 200.000000.  Total average reward 141.000000.
# 1625
# Average reward for episode 200.000000.  Total average reward 141.000000.
# 1630
# Average reward for episode 196.000000.  Total average reward 142.000000.
# 1635
# Average reward for episode 186.000000.  Total average reward 142.000000.
# 1640
# Average reward for episode 200.000000.  Total average reward 143.000000.
# 1645
# Average reward for episode 190.000000.  Total average reward 143.000000.
# 1650
# Average reward for episode 200.000000.  Total average reward 144.000000.
# 1655
# Average reward for episode 189.000000.  Total average reward 144.000000.
# 1660
# Average reward for episode 200.000000.  Total average reward 145.000000.
# 1665
# Average reward for episode 200.000000.  Total average reward 145.000000.
# 1670
# Average reward for episode 200.000000.  Total average reward 146.000000.
# 1675
# Average reward for episode 196.000000.  Total average reward 146.000000.
# 1680
# Average reward for episode 200.000000.  Total average reward 147.000000.
# 1685
# Average reward for episode 187.000000.  Total average reward 147.000000.
# 1690
# Average reward for episode 187.000000.  Total average reward 148.000000.
# 1695
# Average reward for episode 199.000000.  Total average reward 148.000000.
# 1700
# Average reward for episode 182.000000.  Total average reward 149.000000.
# 1705
# Average reward for episode 200.000000.  Total average reward 149.000000.
# 1710
# Average reward for episode 200.000000.  Total average reward 150.000000.
# 1715
# Average reward for episode 195.000000.  Total average reward 150.000000.
# 1720
# Average reward for episode 200.000000.  Total average reward 151.000000.
# 1725
# Average reward for episode 200.000000.  Total average reward 151.000000.
# 1730
# Average reward for episode 183.000000.  Total average reward 151.000000.
# 1735
# Average reward for episode 197.000000.  Total average reward 152.000000.
# 1740
# Average reward for episode 190.000000.  Total average reward 152.000000.
# 1745
# Average reward for episode 200.000000.  Total average reward 153.000000.
# 1750
# Average reward for episode 200.000000.  Total average reward 153.000000.
# 1755
# Average reward for episode 200.000000.  Total average reward 154.000000.
# 1760
# Average reward for episode 200.000000.  Total average reward 154.000000.
# 1765
# Average reward for episode 200.000000.  Total average reward 155.000000.
# 1770
# Average reward for episode 167.000000.  Total average reward 155.000000.
# 1775
# Average reward for episode 184.000000.  Total average reward 155.000000.
# 1780
# Average reward for episode 193.000000.  Total average reward 155.000000.
# 1785
# Average reward for episode 200.000000.  Total average reward 156.000000.
# 1790
# Average reward for episode 200.000000.  Total average reward 156.000000.
# 1795
# Average reward for episode 200.000000.  Total average reward 157.000000.
# 1800
# Average reward for episode 178.000000.  Total average reward 157.000000.
# 1805
# Average reward for episode 200.000000.  Total average reward 157.000000.
# 1810
# Average reward for episode 200.000000.  Total average reward 158.000000.
# 1815
# Average reward for episode 200.000000.  Total average reward 158.000000.
# 1820
# Average reward for episode 200.000000.  Total average reward 159.000000.
# 1825
# Average reward for episode 200.000000.  Total average reward 159.000000.
# 1830
# Average reward for episode 200.000000.  Total average reward 159.000000.
# 1835
# Average reward for episode 200.000000.  Total average reward 160.000000.
# 1840
# Average reward for episode 200.000000.  Total average reward 160.000000.
# 1845
# Average reward for episode 200.000000.  Total average reward 161.000000.
# 1850
# Average reward for episode 193.000000.  Total average reward 161.000000.
# 1855
# Average reward for episode 200.000000.  Total average reward 161.000000.
# 1860
# Average reward for episode 180.000000.  Total average reward 161.000000.
# 1865
# Average reward for episode 200.000000.  Total average reward 162.000000.
# 1870
# Average reward for episode 192.000000.  Total average reward 162.000000.
# 1875
# Average reward for episode 198.000000.  Total average reward 162.000000.
# 1880
# Average reward for episode 200.000000.  Total average reward 163.000000.
# 1885
# Average reward for episode 200.000000.  Total average reward 163.000000.
# 1890
# Average reward for episode 195.000000.  Total average reward 164.000000.
# 1895
# Average reward for episode 200.000000.  Total average reward 164.000000.
# 1900
# Average reward for episode 199.000000.  Total average reward 164.000000.
# 1905
# Average reward for episode 200.000000.  Total average reward 165.000000.
# 1910
# Average reward for episode 197.000000.  Total average reward 165.000000.
# 1915
# Average reward for episode 200.000000.  Total average reward 165.000000.
# 1920
# Average reward for episode 200.000000.  Total average reward 166.000000.
# 1925
# Average reward for episode 193.000000.  Total average reward 166.000000.
# 1930
# Average reward for episode 200.000000.  Total average reward 166.000000.
# 1935
# Average reward for episode 196.000000.  Total average reward 166.000000.
# 1940
# Average reward for episode 177.000000.  Total average reward 167.000000.
# 1945
# Average reward for episode 190.000000.  Total average reward 167.000000.
# 1950
# Average reward for episode 200.000000.  Total average reward 167.000000.
# 1955
# Average reward for episode 200.000000.  Total average reward 167.000000.
# 1960
# Average reward for episode 193.000000.  Total average reward 168.000000.
# 1965
# Average reward for episode 199.000000.  Total average reward 168.000000.
# 1970
# Average reward for episode 191.000000.  Total average reward 168.000000.
# 1975
# Average reward for episode 200.000000.  Total average reward 169.000000.
# 1980
# Average reward for episode 200.000000.  Total average reward 169.000000.
# 1985
# Average reward for episode 195.000000.  Total average reward 169.000000.
# 1990
# Average reward for episode 194.000000.  Total average reward 169.000000.
# 1995
# Average reward for episode 188.000000.  Total average reward 170.000000.
# 2000
# Average reward for episode 195.000000.  Total average reward 170.000000.
# 2005
# Average reward for episode 197.000000.  Total average reward 170.000000.
# 2010
# Average reward for episode 200.000000.  Total average reward 170.000000.
# 2015
# Average reward for episode 191.000000.  Total average reward 171.000000.
# 2020
# Average reward for episode 190.000000.  Total average reward 171.000000.
# 2025
# Average reward for episode 200.000000.  Total average reward 171.000000.
# 2030
# Average reward for episode 193.000000.  Total average reward 171.000000.
# 2035
# Average reward for episode 195.000000.  Total average reward 172.000000.
# 2040
# Average reward for episode 200.000000.  Total average reward 172.000000.
# 2045
# Average reward for episode 200.000000.  Total average reward 172.000000.
# 2050
# Average reward for episode 200.000000.  Total average reward 172.000000.
# 2055
# Average reward for episode 199.000000.  Total average reward 173.000000.
# 2060
# Average reward for episode 191.000000.  Total average reward 173.000000.
# 2065
# Average reward for episode 182.000000.  Total average reward 173.000000.
# 2070
# Average reward for episode 200.000000.  Total average reward 173.000000.
# 2075
# Average reward for episode 181.000000.  Total average reward 173.000000.
# 2080
# Average reward for episode 194.000000.  Total average reward 173.000000.
# 2085
# Average reward for episode 188.000000.  Total average reward 174.000000.
# 2090
# Average reward for episode 200.000000.  Total average reward 174.000000.
# 2095
# Average reward for episode 200.000000.  Total average reward 174.000000.
# 2100
# Average reward for episode 195.000000.  Total average reward 174.000000.
# 2105
# Average reward for episode 190.000000.  Total average reward 174.000000.
# 2110
# Average reward for episode 196.000000.  Total average reward 175.000000.
# 2115
# Average reward for episode 200.000000.  Total average reward 175.000000.
# 2120
# Average reward for episode 200.000000.  Total average reward 175.000000.
# 2125
# Average reward for episode 200.000000.  Total average reward 175.000000.
# 2130
# Average reward for episode 194.000000.  Total average reward 176.000000.
# 2135
# Average reward for episode 194.000000.  Total average reward 176.000000.
# 2140
# Average reward for episode 196.000000.  Total average reward 176.000000.
# 2145
# Average reward for episode 200.000000.  Total average reward 176.000000.
# 2150
# Average reward for episode 192.000000.  Total average reward 176.000000.
# 2155
# Average reward for episode 189.000000.  Total average reward 177.000000.
# 2160
# Average reward for episode 191.000000.  Total average reward 177.000000.
# 2165
# Average reward for episode 181.000000.  Total average reward 177.000000.
# 2170
# Average reward for episode 198.000000.  Total average reward 177.000000.
# 2175
# Average reward for episode 200.000000.  Total average reward 177.000000.
# 2180
# Average reward for episode 187.000000.  Total average reward 177.000000.
# 2185
# Average reward for episode 200.000000.  Total average reward 177.000000.
# 2190
# Average reward for episode 175.000000.  Total average reward 177.000000.
# 2195
# Average reward for episode 200.000000.  Total average reward 178.000000.
# 2200
# Average reward for episode 200.000000.  Total average reward 178.000000.
# 2205
# Average reward for episode 189.000000.  Total average reward 178.000000.
# 2210
# Average reward for episode 180.000000.  Total average reward 178.000000.
# 2215
# Average reward for episode 200.000000.  Total average reward 178.000000.
# 2220
# Average reward for episode 200.000000.  Total average reward 178.000000.
# 2225
# Average reward for episode 200.000000.  Total average reward 179.000000.
# 2230
# Average reward for episode 200.000000.  Total average reward 179.000000.
# 2235
# Average reward for episode 177.000000.  Total average reward 179.000000.
# 2240
# Average reward for episode 200.000000.  Total average reward 179.000000.
# 2245
# Average reward for episode 194.000000.  Total average reward 179.000000.
# 2250
# Average reward for episode 200.000000.  Total average reward 179.000000.
# 2255
# Average reward for episode 200.000000.  Total average reward 180.000000.
# 2260
# Average reward for episode 200.000000.  Total average reward 180.000000.
# 2265
# Average reward for episode 193.000000.  Total average reward 180.000000.
# 2270
# Average reward for episode 200.000000.  Total average reward 180.000000.
# 2275
# Average reward for episode 200.000000.  Total average reward 180.000000.
# 2280
# Average reward for episode 200.000000.  Total average reward 180.000000.
# 2285
# Average reward for episode 191.000000.  Total average reward 181.000000.
# 2290
# Average reward for episode 200.000000.  Total average reward 181.000000.
# 2295
# Average reward for episode 200.000000.  Total average reward 181.000000.
# 2300
# Average reward for episode 191.000000.  Total average reward 181.000000.
# 2305
# Average reward for episode 200.000000.  Total average reward 181.000000.
# 2310
# Average reward for episode 194.000000.  Total average reward 181.000000.
# 2315
# Average reward for episode 200.000000.  Total average reward 182.000000.
# 2320
# Average reward for episode 200.000000.  Total average reward 182.000000.
# 2325
# Average reward for episode 200.000000.  Total average reward 182.000000.
# 2330
# Average reward for episode 200.000000.  Total average reward 182.000000.
# 2335
# Average reward for episode 200.000000.  Total average reward 182.000000.
# 2340
# Average reward for episode 200.000000.  Total average reward 182.000000.
# 2345
# Average reward for episode 194.000000.  Total average reward 183.000000.
# 2350
# Average reward for episode 192.000000.  Total average reward 183.000000.
# 2355
# Average reward for episode 196.000000.  Total average reward 183.000000.
# 2360
# Average reward for episode 200.000000.  Total average reward 183.000000.
# 2365
# Average reward for episode 190.000000.  Total average reward 183.000000.
# 2370
# Average reward for episode 200.000000.  Total average reward 183.000000.
# 2375
# Average reward for episode 190.000000.  Total average reward 183.000000.
# 2380
# Average reward for episode 200.000000.  Total average reward 183.000000.
# 2385
# Average reward for episode 200.000000.  Total average reward 184.000000.
# 2390
# Average reward for episode 189.000000.  Total average reward 184.000000.
# 2395
# Average reward for episode 200.000000.  Total average reward 184.000000.
# 2400
# Average reward for episode 200.000000.  Total average reward 184.000000.
# 2405
# Average reward for episode 200.000000.  Total average reward 184.000000.
# 2410
# Average reward for episode 200.000000.  Total average reward 184.000000.
# 2415
# Average reward for episode 197.000000.  Total average reward 184.000000.
# 2420
# Average reward for episode 193.000000.  Total average reward 184.000000.
# 2425
# Average reward for episode 200.000000.  Total average reward 185.000000.
# 2430
# Average reward for episode 188.000000.  Total average reward 185.000000.
# 2435
# Average reward for episode 200.000000.  Total average reward 185.000000.
# 2440
# Average reward for episode 200.000000.  Total average reward 185.000000.
# 2445
# Average reward for episode 200.000000.  Total average reward 185.000000.
# 2450
# Average reward for episode 200.000000.  Total average reward 185.000000.
# 2455
# Average reward for episode 198.000000.  Total average reward 185.000000.
# 2460
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 2465
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 2470
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 2475
# Average reward for episode 195.000000.  Total average reward 186.000000.
# 2480
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 2485
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 2490
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 2495
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 2500
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 2505
# Average reward for episode 197.000000.  Total average reward 187.000000.
# 2510
# Average reward for episode 193.000000.  Total average reward 187.000000.
# 2515
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 2520
# Average reward for episode 180.000000.  Total average reward 187.000000.
# 2525
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 2530
# Average reward for episode 190.000000.  Total average reward 187.000000.
# 2535
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 2540
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 2545
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 2550
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 2555
# Average reward for episode 184.000000.  Total average reward 187.000000.
# 2560
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 2565
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 2570
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 2575
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 2580
# Average reward for episode 181.000000.  Total average reward 188.000000.
# 2585
# Average reward for episode 192.000000.  Total average reward 188.000000.
# 2590
# Average reward for episode 186.000000.  Total average reward 188.000000.
# 2595
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 2600
# Average reward for episode 199.000000.  Total average reward 188.000000.
# 2605
# Average reward for episode 197.000000.  Total average reward 188.000000.
# 2610
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 2615
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 2620
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 2625
# Average reward for episode 191.000000.  Total average reward 188.000000.
# 2630
# Average reward for episode 198.000000.  Total average reward 189.000000.
# 2635
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 2640
# Average reward for episode 190.000000.  Total average reward 189.000000.
# 2645
# Average reward for episode 196.000000.  Total average reward 189.000000.
# 2650
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 2655
# Average reward for episode 187.000000.  Total average reward 189.000000.
# 2660
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 2665
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 2670
# Average reward for episode 198.000000.  Total average reward 189.000000.
# 2675
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 2680
# Average reward for episode 190.000000.  Total average reward 189.000000.
# 2685
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 2690
# Average reward for episode 198.000000.  Total average reward 189.000000.
# 2695
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 2700
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 2705
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 2710
# Average reward for episode 198.000000.  Total average reward 190.000000.
# 2715
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 2720
# Average reward for episode 194.000000.  Total average reward 190.000000.
# 2725
# Average reward for episode 197.000000.  Total average reward 190.000000.
# 2730
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 2735
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 2740
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 2745
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 2750
# Average reward for episode 197.000000.  Total average reward 190.000000.
# 2755
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 2760
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 2765
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 2770
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 2775
# Average reward for episode 185.000000.  Total average reward 191.000000.
# 2780
# Average reward for episode 191.000000.  Total average reward 191.000000.
# 2785
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 2790
# Average reward for episode 193.000000.  Total average reward 191.000000.
# 2795
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 2800
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 2805
# Average reward for episode 189.000000.  Total average reward 191.000000.
# 2810
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 2815
# Average reward for episode 198.000000.  Total average reward 191.000000.
# 2820
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 2825
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 2830
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 2835
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 2840
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 2845
# Average reward for episode 191.000000.  Total average reward 192.000000.
# 2850
# Average reward for episode 187.000000.  Total average reward 192.000000.
# 2855
# Average reward for episode 198.000000.  Total average reward 192.000000.
# 2860
# Average reward for episode 175.000000.  Total average reward 191.000000.
# 2865
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 2870
# Average reward for episode 176.000000.  Total average reward 191.000000.
# 2875
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 2880
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 2885
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 2890
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 2895
# Average reward for episode 185.000000.  Total average reward 192.000000.
# 2900
# Average reward for episode 199.000000.  Total average reward 192.000000.
# 2905
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 2910
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 2915
# Average reward for episode 197.000000.  Total average reward 192.000000.
# 2920
# Average reward for episode 189.000000.  Total average reward 192.000000.
# 2925
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 2930
# Average reward for episode 198.000000.  Total average reward 192.000000.
# 2935
# Average reward for episode 198.000000.  Total average reward 192.000000.
# 2940
# Average reward for episode 184.000000.  Total average reward 192.000000.
# 2945
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 2950
# Average reward for episode 185.000000.  Total average reward 192.000000.
# 2955
# Average reward for episode 190.000000.  Total average reward 192.000000.
# 2960
# Average reward for episode 191.000000.  Total average reward 192.000000.
# 2965
# Average reward for episode 192.000000.  Total average reward 192.000000.
# 2970
# Average reward for episode 158.000000.  Total average reward 192.000000.
# 2975
# Average reward for episode 179.000000.  Total average reward 191.000000.
# 2980
# Average reward for episode 188.000000.  Total average reward 191.000000.
# 2985
# Average reward for episode 178.000000.  Total average reward 191.000000.
# 2990
# Average reward for episode 169.000000.  Total average reward 191.000000.
# 2995
# Average reward for episode 193.000000.  Total average reward 191.000000.
# 3000
# Average reward for episode 199.000000.  Total average reward 191.000000.
# 3005
# Average reward for episode 162.000000.  Total average reward 191.000000.
# 3010
# Average reward for episode 192.000000.  Total average reward 191.000000.
# 3015
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 3020
# Average reward for episode 187.000000.  Total average reward 191.000000.
# 3025
# Average reward for episode 180.000000.  Total average reward 191.000000.
# 3030
# Average reward for episode 180.000000.  Total average reward 191.000000.
# 3035
# Average reward for episode 180.000000.  Total average reward 191.000000.
# 3040
# Average reward for episode 192.000000.  Total average reward 191.000000.
# 3045
# Average reward for episode 187.000000.  Total average reward 191.000000.
# 3050
# Average reward for episode 184.000000.  Total average reward 191.000000.
# 3055
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 3060
# Average reward for episode 189.000000.  Total average reward 191.000000.
# 3065
# Average reward for episode 161.000000.  Total average reward 190.000000.
# 3070
# Average reward for episode 199.000000.  Total average reward 190.000000.
# 3075
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 3080
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 3085
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 3090
# Average reward for episode 189.000000.  Total average reward 191.000000.
# 3095
# Average reward for episode 191.000000.  Total average reward 191.000000.
# 3100
# Average reward for episode 165.000000.  Total average reward 190.000000.
# 3105
# Average reward for episode 191.000000.  Total average reward 190.000000.
# 3110
# Average reward for episode 185.000000.  Total average reward 190.000000.
# 3115
# ...
# 8980
# Average reward for episode 192.000000.  Total average reward 184.000000.
# 8985
# Average reward for episode 185.000000.  Total average reward 184.000000.
# 8990
# Average reward for episode 183.000000.  Total average reward 184.000000.
# 8995
# Average reward for episode 196.000000.  Total average reward 184.000000.
# 9000
# Average reward for episode 197.000000.  Total average reward 185.000000.
# 9005
# Average reward for episode 198.000000.  Total average reward 185.000000.
# 9010
# Average reward for episode 184.000000.  Total average reward 185.000000.
# 9015
# Average reward for episode 195.000000.  Total average reward 185.000000.
# 9020
# Average reward for episode 193.000000.  Total average reward 185.000000.
# 9025
# Average reward for episode 199.000000.  Total average reward 185.000000.
# 9030
# Average reward for episode 200.000000.  Total average reward 185.000000.
# 9035
# Average reward for episode 174.000000.  Total average reward 185.000000.
# 9040
# Average reward for episode 180.000000.  Total average reward 185.000000.
# 9045
# Average reward for episode 181.000000.  Total average reward 185.000000.
# 9050
# Average reward for episode 198.000000.  Total average reward 185.000000.
# 9055
# Average reward for episode 193.000000.  Total average reward 185.000000.
# 9060
# Average reward for episode 195.000000.  Total average reward 185.000000.
# 9065
# Average reward for episode 186.000000.  Total average reward 185.000000.
# 9070
# Average reward for episode 186.000000.  Total average reward 185.000000.
# 9075
# Average reward for episode 191.000000.  Total average reward 185.000000.
# 9080
# Average reward for episode 198.000000.  Total average reward 185.000000.
# 9085
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 9090
# Average reward for episode 192.000000.  Total average reward 186.000000.
# 9095
# Average reward for episode 191.000000.  Total average reward 186.000000.
# 9100
# Average reward for episode 185.000000.  Total average reward 186.000000.
# 9105
# Average reward for episode 184.000000.  Total average reward 186.000000.
# 9110
# Average reward for episode 196.000000.  Total average reward 186.000000.
# 9115
# Average reward for episode 189.000000.  Total average reward 186.000000.
# 9120
# Average reward for episode 190.000000.  Total average reward 186.000000.
# 9125
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 9130
# Average reward for episode 188.000000.  Total average reward 186.000000.
# 9135
# Average reward for episode 189.000000.  Total average reward 186.000000.
# 9140
# Average reward for episode 185.000000.  Total average reward 186.000000.
# 9145
# Average reward for episode 191.000000.  Total average reward 186.000000.
# 9150
# Average reward for episode 198.000000.  Total average reward 186.000000.
# 9155
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 9160
# Average reward for episode 195.000000.  Total average reward 186.000000.
# 9165
# Average reward for episode 193.000000.  Total average reward 186.000000.
# 9170
# Average reward for episode 197.000000.  Total average reward 187.000000.
# 9175
# Average reward for episode 197.000000.  Total average reward 187.000000.
# 9180
# Average reward for episode 197.000000.  Total average reward 187.000000.
# 9185
# Average reward for episode 182.000000.  Total average reward 187.000000.
# 9190
# Average reward for episode 190.000000.  Total average reward 187.000000.
# 9195
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 9200
# Average reward for episode 194.000000.  Total average reward 187.000000.
# 9205
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 9210
# Average reward for episode 197.000000.  Total average reward 187.000000.
# 9215
# Average reward for episode 190.000000.  Total average reward 187.000000.
# 9220
# Average reward for episode 192.000000.  Total average reward 187.000000.
# 9225
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 9230
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 9235
# Average reward for episode 194.000000.  Total average reward 188.000000.
# 9240
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9245
# Average reward for episode 195.000000.  Total average reward 188.000000.
# 9250
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9255
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9260
# Average reward for episode 191.000000.  Total average reward 188.000000.
# 9265
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9270
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9275
# Average reward for episode 199.000000.  Total average reward 188.000000.
# 9280
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9285
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9290
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9295
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9300
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9305
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9310
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9315
# Average reward for episode 188.000000.  Total average reward 189.000000.
# 9320
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9325
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9330
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9335
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 9340
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 9345
# Average reward for episode 192.000000.  Total average reward 190.000000.
# 9350
# Average reward for episode 196.000000.  Total average reward 190.000000.
# 9355
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 9360
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 9365
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 9370
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 9375
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 9380
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 9385
# Average reward for episode 195.000000.  Total average reward 190.000000.
# 9390
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 9395
# Average reward for episode 200.000000.  Total average reward 190.000000.
# 9400
# Average reward for episode 194.000000.  Total average reward 191.000000.
# 9405
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 9410
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 9415
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 9420
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 9425
# Average reward for episode 193.000000.  Total average reward 191.000000.
# 9430
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 9435
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 9440
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 9445
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 9450
# Average reward for episode 190.000000.  Total average reward 191.000000.
# 9455
# Average reward for episode 189.000000.  Total average reward 191.000000.
# 9460
# Average reward for episode 199.000000.  Total average reward 191.000000.
# 9465
# Average reward for episode 196.000000.  Total average reward 191.000000.
# 9470
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 9475
# Average reward for episode 199.000000.  Total average reward 191.000000.
# 9480
# Average reward for episode 186.000000.  Total average reward 191.000000.
# 9485
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 9490
# Average reward for episode 182.000000.  Total average reward 191.000000.
# 9495
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 9500
# Average reward for episode 194.000000.  Total average reward 192.000000.
# 9505
# Average reward for episode 194.000000.  Total average reward 192.000000.
# 9510
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 9515
# Average reward for episode 193.000000.  Total average reward 192.000000.
# 9520
# Average reward for episode 197.000000.  Total average reward 192.000000.
# 9525
# Average reward for episode 194.000000.  Total average reward 192.000000.
# 9530
# Average reward for episode 199.000000.  Total average reward 192.000000.
# 9535
# Average reward for episode 195.000000.  Total average reward 192.000000.
# 9540
# Average reward for episode 177.000000.  Total average reward 192.000000.
# 9545
# Average reward for episode 188.000000.  Total average reward 192.000000.
# 9550
# Average reward for episode 190.000000.  Total average reward 192.000000.
# 9555
# Average reward for episode 200.000000.  Total average reward 192.000000.
# 9560
# Average reward for episode 182.000000.  Total average reward 192.000000.
# 9565
# Average reward for episode 195.000000.  Total average reward 192.000000.
# 9570
# Average reward for episode 191.000000.  Total average reward 192.000000.
# 9575
# Average reward for episode 177.000000.  Total average reward 191.000000.
# 9580
# Average reward for episode 168.000000.  Total average reward 191.000000.
# 9585
# Average reward for episode 180.000000.  Total average reward 191.000000.
# 9590
# Average reward for episode 189.000000.  Total average reward 191.000000.
# 9595
# Average reward for episode 192.000000.  Total average reward 191.000000.
# 9600
# Average reward for episode 185.000000.  Total average reward 191.000000.
# 9605
# Average reward for episode 186.000000.  Total average reward 191.000000.
# 9610
# Average reward for episode 194.000000.  Total average reward 191.000000.
# 9615
# Average reward for episode 158.000000.  Total average reward 191.000000.
# 9620
# Average reward for episode 186.000000.  Total average reward 191.000000.
# 9625
# Average reward for episode 200.000000.  Total average reward 191.000000.
# 9630
# Average reward for episode 176.000000.  Total average reward 191.000000.
# 9635
# Average reward for episode 167.000000.  Total average reward 190.000000.
# 9640
# Average reward for episode 166.000000.  Total average reward 190.000000.
# 9645
# Average reward for episode 157.000000.  Total average reward 190.000000.
# 9650
# Average reward for episode 183.000000.  Total average reward 190.000000.
# 9655
# Average reward for episode 176.000000.  Total average reward 190.000000.
# 9660
# Average reward for episode 177.000000.  Total average reward 189.000000.
# 9665
# Average reward for episode 148.000000.  Total average reward 189.000000.
# 9670
# Average reward for episode 178.000000.  Total average reward 189.000000.
# 9675
# Average reward for episode 176.000000.  Total average reward 189.000000.
# 9680
# Average reward for episode 185.000000.  Total average reward 189.000000.
# 9685
# Average reward for episode 187.000000.  Total average reward 189.000000.
# 9690
# Average reward for episode 177.000000.  Total average reward 189.000000.
# 9695
# Average reward for episode 163.000000.  Total average reward 188.000000.
# 9700
# Average reward for episode 174.000000.  Total average reward 188.000000.
# 9705
# Average reward for episode 199.000000.  Total average reward 188.000000.
# 9710
# Average reward for episode 164.000000.  Total average reward 188.000000.
# 9715
# Average reward for episode 165.000000.  Total average reward 188.000000.
# 9720
# Average reward for episode 147.000000.  Total average reward 187.000000.
# 9725
# Average reward for episode 172.000000.  Total average reward 187.000000.
# 9730
# Average reward for episode 171.000000.  Total average reward 187.000000.
# 9735
# Average reward for episode 152.000000.  Total average reward 187.000000.
# 9740
# Average reward for episode 171.000000.  Total average reward 187.000000.
# 9745
# Average reward for episode 180.000000.  Total average reward 187.000000.
# 9750
# Average reward for episode 155.000000.  Total average reward 186.000000.
# 9755
# Average reward for episode 188.000000.  Total average reward 186.000000.
# 9760
# Average reward for episode 172.000000.  Total average reward 186.000000.
# 9765
# Average reward for episode 188.000000.  Total average reward 186.000000.
# 9770
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 9775
# Average reward for episode 188.000000.  Total average reward 186.000000.
# 9780
# Average reward for episode 179.000000.  Total average reward 186.000000.
# 9785
# Average reward for episode 181.000000.  Total average reward 186.000000.
# 9790
# Average reward for episode 163.000000.  Total average reward 186.000000.
# 9795
# Average reward for episode 167.000000.  Total average reward 186.000000.
# 9800
# Average reward for episode 187.000000.  Total average reward 186.000000.
# 9805
# Average reward for episode 195.000000.  Total average reward 186.000000.
# 9810
# Average reward for episode 184.000000.  Total average reward 186.000000.
# 9815
# Average reward for episode 194.000000.  Total average reward 186.000000.
# 9820
# Average reward for episode 198.000000.  Total average reward 186.000000.
# 9825
# Average reward for episode 189.000000.  Total average reward 186.000000.
# 9830
# Average reward for episode 187.000000.  Total average reward 186.000000.
# 9835
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 9840
# Average reward for episode 192.000000.  Total average reward 186.000000.
# 9845
# Average reward for episode 195.000000.  Total average reward 186.000000.
# 9850
# Average reward for episode 200.000000.  Total average reward 186.000000.
# 9855
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 9860
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 9865
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 9870
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 9875
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 9880
# Average reward for episode 199.000000.  Total average reward 187.000000.
# 9885
# Average reward for episode 195.000000.  Total average reward 187.000000.
# 9890
# Average reward for episode 194.000000.  Total average reward 187.000000.
# 9895
# Average reward for episode 200.000000.  Total average reward 187.000000.
# 9900
# Average reward for episode 192.000000.  Total average reward 188.000000.
# 9905
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9910
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9915
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9920
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9925
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9930
# Average reward for episode 196.000000.  Total average reward 188.000000.
# 9935
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9940
# Average reward for episode 200.000000.  Total average reward 188.000000.
# 9945
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9950
# Average reward for episode 194.000000.  Total average reward 189.000000.
# 9955
# Average reward for episode 194.000000.  Total average reward 189.000000.
# 9960
# Average reward for episode 192.000000.  Total average reward 189.000000.
# 9965
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9970
# Average reward for episode 194.000000.  Total average reward 189.000000.
# 9975
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9980
# Average reward for episode 193.000000.  Total average reward 189.000000.
# 9985
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9990
# Average reward for episode 200.000000.  Total average reward 189.000000.
# 9995
# Average reward for episode 189.000000.  Total average reward 189.000000.
# 10000
# 10001 Episodes completed.

# %%
saver = tf.train.Saver()
saver_path = saver.save(sess,"./PG_cartpole_weights.ckpt")

# %%
sess.close()

# %%
#infrrence logic
sess = tf.Session(config=config)
saver = tf.train.Saver()
saver.restore(sess,"./PG_cartpole_weights.ckpt")
# Out:
# INFO:tensorflow:Restoring parameters from ./PG_cartpole_weights.ckpt

# %%
obs =env.reset()
x = np.reshape(observation,[1,D])

# %%
tf_prob = sess.run(probability,feed_dict={observations:x})

# %%
action = 1 if tf_prob > 0.5 else 0

# %%
env.reset()
env.mode = "human"
random_episodes = 0
reward_sum = 0
while random_episodes < 100:
    env.render()
    observation, reward, done, _ = env.step(action)
    x = np.reshape(observation,[1,D])
    action = 1 if sess.run(probability,feed_dict={observations:x}) > 0.5 else 0
    reward_sum += reward
    if done:
        random_episodes += 1
        print("Reward for this episode was:",reward_sum)
        reward_sum = 0
        env.reset()
# Out:
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0
# Reward for this episode was: 200.0

# %% [markdown]
# As you can see, the network not only does much better than random actions, but achieves the goal of 200 points per episode, thus solving the task!

# %%
episodic_average = []
total_average = []
with open("PG_rewards.txt") as f:
    for i in f.readlines():
        sample = i.split("  ")
        episodic_average.append(float(sample[0][27:-1]))#,sample[1][21]
        total_average.append(sample[1][20:])
# Out:
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  18.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  19.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  20.000000.
#
#  21.000000.
#
#  21.000000.
#
#  21.000000.
#
#  21.000000.
#
#  21.000000.
#
#  21.000000.
#
#  21.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  22.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  23.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  24.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  25.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  26.000000.
#
#  27.000000.
#
#  27.000000.
#
#  27.000000.
#
#  27.000000.
#
#  28.000000.
#
#  28.000000.
#
#  28.000000.
#
#  28.000000.
#
#  28.000000.
#
#  28.000000.
#
#  28.000000.
#
#  29.000000.
#
#  29.000000.
#
#  29.000000.
#
#  29.000000.
#
#  30.000000.
#
#  30.000000.
#
#  30.000000.
#
#  30.000000.
#
#  30.000000.
#
#  30.000000.
#
#  31.000000.
#
#  31.000000.
#
#  32.000000.
#
#  32.000000.
#
#  32.000000.
#
#  32.000000.
#
#  33.000000.
#
#  33.000000.
#
#  33.000000.
#
#  33.000000.
#
#  34.000000.
#
#  34.000000.
#
#  34.000000.
#
#  35.000000.
#
#  35.000000.
#
#  35.000000.
#
#  36.000000.
#
#  36.000000.
#
#  36.000000.
#
#  36.000000.
#
#  36.000000.
#
#  37.000000.
#
#  37.000000.
#
#  37.000000.
#
#  38.000000.
#
#  38.000000.
#
#  38.000000.
#
#  38.000000.
#
#  39.000000.
#
#  39.000000.
#
#  40.000000.
#
#  40.000000.
#
#  41.000000.
#
#  41.000000.
#
#  42.000000.
#
#  43.000000.
#
#  43.000000.
#
#  44.000000.
#
#  45.000000.
#
#  46.000000.
#
#  47.000000.
#
#  48.000000.
#
#  48.000000.
#
#  49.000000.
#
#  49.000000.
#
#  50.000000.
#
#  50.000000.
#
#  51.000000.
#
#  52.000000.
#
#  53.000000.
#
#  54.000000.
#
#  55.000000.
#
#  55.000000.
#
#  56.000000.
#
#  56.000000.
#
#  57.000000.
#
#  57.000000.
#
#  58.000000.
#
#  59.000000.
#
#  60.000000.
#
#  60.000000.
#
#  61.000000.
#
#  62.000000.
#
#  62.000000.
#
#  63.000000.
#
#  63.000000.
#
#  64.000000.
#
#  65.000000.
#
#  66.000000.
#
#  66.000000.
#
#  67.000000.
#
#  68.000000.
#
#  69.000000.
#
#  70.000000.
#
#  71.000000.
#
#  72.000000.
#
#  73.000000.
#
#  74.000000.
#
#  75.000000.
#
#  76.000000.
#
#  76.000000.
#
#  78.000000.
#
#  78.000000.
#
#  79.000000.
#
#  80.000000.
#
#  81.000000.
#
#  82.000000.
#
#  83.000000.
#
#  83.000000.
#
#  85.000000.
#
#  85.000000.
#
#  86.000000.
#
#  87.000000.
#
#  88.000000.
#
#  89.000000.
#
#  90.000000.
#
#  91.000000.
#
#  92.000000.
#
#  93.000000.
#
#  94.000000.
#
#  95.000000.
#
#  96.000000.
#
#  97.000000.
#
#  97.000000.
#
#  98.000000.
#
#  99.000000.
#
#  100.000000.
#
#  100.000000.
#
#  101.000000.
#
#  102.000000.
#
#  103.000000.
#
#  103.000000.
#
#  104.000000.
#
#  105.000000.
#
#  106.000000.
#
#  107.000000.
#
#  107.000000.
#
#  108.000000.
#
#  109.000000.
#
#  109.000000.
#
#  110.000000.
#
#  111.000000.
#
#  111.000000.
#
#  112.000000.
#
#  113.000000.
#
#  113.000000.
#
#  114.000000.
#
#  115.000000.
#
#  116.000000.
#
#  116.000000.
#
#  117.000000.
#
#  117.000000.
#
#  118.000000.
#
#  119.000000.
#
#  119.000000.
#
#  120.000000.
#
#  121.000000.
#
#  121.000000.
#
#  122.000000.
#
#  122.000000.
#
#  123.000000.
#
#  123.000000.
#
#  124.000000.
#
#  125.000000.
#
#  125.000000.
#
#  126.000000.
#
#  126.000000.
#
#  127.000000.
#
#  127.000000.
#
#  128.000000.
#
#  128.000000.
#
#  129.000000.
#
#  130.000000.
#
#  130.000000.
#
#  131.000000.
#
#  132.000000.
#
#  132.000000.
#
#  133.000000.
#
#  133.000000.
#
#  134.000000.
#
#  135.000000.
#
#  135.000000.
#
#  136.000000.
#
#  137.000000.
#
#  137.000000.
#
#  138.000000.
#
#  138.000000.
#
#  139.000000.
#
#  140.000000.
#
#  140.000000.
#
#  140.000000.
#
#  141.000000.
#
#  142.000000.
#
#  142.000000.
#
#  142.000000.
#
#  143.000000.
#
#  143.000000.
#
#  144.000000.
#
#  144.000000.
#
#  145.000000.
#
#  145.000000.
#
#  146.000000.
#
#  146.000000.
#
#  147.000000.
#
#  147.000000.
#
#  148.000000.
#
#  148.000000.
#
#  148.000000.
#
#  149.000000.
#
#  149.000000.
#
#  150.000000.
#
#  150.000000.
#
#  150.000000.
#
#  151.000000.
#
#  151.000000.
#
#  152.000000.
#
#  152.000000.
#
#  153.000000.
#
#  153.000000.
#
#  153.000000.
#
#  153.000000.
#
#  154.000000.
#
#  154.000000.
#
#  155.000000.
#
#  155.000000.
#
#  156.000000.
#
#  156.000000.
#
#  156.000000.
#
#  157.000000.
#
#  157.000000.
#
#  158.000000.
#
#  158.000000.
#
#  158.000000.
#
#  159.000000.
#
#  159.000000.
#
#  159.000000.
#
#  160.000000.
#
#  160.000000.
#
#  161.000000.
#
#  161.000000.
#
#  161.000000.
#
#  162.000000.
#
#  162.000000.
#
#  162.000000.
#
#  162.000000.
#
#  163.000000.
#
#  163.000000.
#
#  163.000000.
#
#  164.000000.
#
#  164.000000.
#
#  164.000000.
#
#  165.000000.
#
#  165.000000.
#
#  165.000000.
#
#  166.000000.
#
#  166.000000.
#
#  166.000000.
#
#  166.000000.
#
#  167.000000.
#
#  167.000000.
#
#  167.000000.
#
#  168.000000.
#
#  168.000000.
#
#  168.000000.
#
#  168.000000.
#
#  169.000000.
#
#  169.000000.
#
#  169.000000.
#
#  169.000000.
#
#  170.000000.
#
#  170.000000.
#
#  170.000000.
#
#  171.000000.
#
#  171.000000.
#
#  171.000000.
#
#  171.000000.
#
#  172.000000.
#
#  172.000000.
#
#  172.000000.
#
#  172.000000.
#
#  173.000000.
#
#  173.000000.
#
#  173.000000.
#
#  173.000000.
#
#  174.000000.
#
#  174.000000.
#
#  174.000000.
#
#  174.000000.
#
#  175.000000.
#
#  175.000000.
#
#  175.000000.
#
#  175.000000.
#
#  176.000000.
#
#  176.000000.
#
#  176.000000.
#
#  176.000000.
#
#  177.000000.
#
#  177.000000.
#
#  177.000000.
#
#  177.000000.
#
#  177.000000.
#
#  178.000000.
#
#  178.000000.
#
#  178.000000.
#
#  178.000000.
#
#  178.000000.
#
#  179.000000.
#
#  179.000000.
#
#  179.000000.
#
#  179.000000.
#
#  180.000000.
#
#  180.000000.
#
#  180.000000.
#
#  180.000000.
#
#  180.000000.
#
#  180.000000.
#
#  181.000000.
#
#  181.000000.
#
#  181.000000.
#
#  181.000000.
#
#  181.000000.
#
#  182.000000.
#
#  182.000000.
#
#  182.000000.
#
#  182.000000.
#
#  182.000000.
#
#  182.000000.
#
#  182.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  183.000000.
#
#  184.000000.
#
#  184.000000.
#
#  184.000000.
#
#  184.000000.
#
#  184.000000.
#
#  184.000000.
#
#  184.000000.
#
#  184.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  185.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  186.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  187.000000.
#
#  188.000000.
#
#  188.000000.
#
#  188.000000.
#
#  188.000000.
#
#  188.000000.
#
#  188.000000.
#
#  188.000000.
#
#  188.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  189.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  190.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  191.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  192.000000.
#
#  193.000000.
#
#  192.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  193.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  194.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  197.000000.
#
#  197.000000.
#
#  198.000000.
#
#  197.000000.
#
#  198.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  195.000000.
#
#  196.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  198.000000.
#
#  198.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  199.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  195.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  197.000000.
#
#  197.000000.
#
#  196.000000.
#
#  197.000000.
#
#  197.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  196.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  197.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
#
#  198.000000.
