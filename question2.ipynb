# %%
import numpy as np
import gym
env = gym.make('Pong-v0')

# %%
env.reset()
random_episodes = 0
reward_sum = 0
while random_episodes < 10:
    env.render()
    observation, reward, done, _ = env.step(np.random.randint(0,5))
    reward_sum += reward
    if done:
        random_episodes += 1
        print("Reward for this episode was:",reward_sum)
        reward_sum = 0
        env.reset()
# Out:
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# 0.0 False {'ale.lives': 0}
# ...

# %%
observation.shape
# Out:
# (210, 160, 3)

# %%
210*160* 3
# Out:
# 100800

# %%
80*80*3
# Out:
# 19200
